# %% [markdown]
# # Information Retrieval Coursework (7071CEM)
#
# Task:
# Develop a vertical search engine similar to Google Scholar that only retrieves papers/books published by a member of Coventry University. As such, at least one of the co-authors must be a Coventry University Staff member.
#
# To this end, the profiles of academic staff at CU available on the CU web site are crawled, and their papers within their profiles are indexed.

# %% [markdown]
# ## Package Installs
#
# Some packages required for this task are by default not included in the jupyter notebooks package list. A pip-install of these packages is required.

# %%
# Delete the "#" before each subsequent line to install the package

#!pip install scrapy
#!pip install requests
#!pip install BeautifulSoup4
#!pip install nltk
#!pip install gensim
#!pip install xgboost
#!pip install pandastable
# Out:
# Requirement already satisfied: scrapy in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (2.9.0)
# Requirement already satisfied: Twisted>=18.9.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (22.10.0)
# Requirement already satisfied: cryptography>=3.4.6 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (41.0.1)
# Requirement already satisfied: cssselect>=0.9.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: parsel>=1.5.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (1.8.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (23.2.0)
# Requirement already satisfied: queuelib>=1.4.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: service-identity>=18.1.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (23.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (2.1.1)
# Requirement already satisfied: zope.interface>=5.1.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (6.0)
# Requirement already satisfied: protego>=0.1.15 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (0.2.1)
# Requirement already satisfied: itemadapter>=0.1.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (0.8.0)
# Requirement already satisfied: setuptools in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (68.0.0)
# Requirement already satisfied: packaging in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (23.1)
# Requirement already satisfied: tldextract in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (3.4.4)
# Requirement already satisfied: lxml>=4.3.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (4.9.3)
# Requirement already satisfied: PyDispatcher>=2.0.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=3.4.6->scrapy) (1.15.1)
# Requirement already satisfied: jmespath>=0.9.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: six in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from protego>=0.1.15->scrapy) (1.16.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from service-identity>=18.1.0->scrapy) (23.1.0)
# Requirement already satisfied: pyasn1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.5.0)
# Requirement already satisfied: pyasn1-modules in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.3.0)
# Requirement already satisfied: constantly>=15.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from Twisted>=18.9.0->scrapy) (15.1.0)
# Requirement already satisfied: incremental>=21.3.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: Automat>=0.8.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from Twisted>=18.9.0->scrapy) (4.6.3)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from Twisted>=18.9.0->scrapy) (1.0.3)
# Requirement already satisfied: idna in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from tldextract->scrapy) (3.4)
# Requirement already satisfied: requests>=2.1.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from tldextract->scrapy) (2.31.0)
# Requirement already satisfied: requests-file>=1.4 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from tldextract->scrapy) (3.12.2)
# Requirement already satisfied: pycparser in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.12->cryptography>=3.4.6->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2023.5.7)
# Requirement already satisfied: requests in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests) (2023.5.7)
# Requirement already satisfied: BeautifulSoup4 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from BeautifulSoup4) (2.4.1)
# Requirement already satisfied: nltk in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.1.4)
# Requirement already satisfied: joblib in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from nltk) (1.3.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: gensim in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.25.0)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.11.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from gensim) (6.3.0)
# Requirement already satisfied: xgboost in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (1.7.6)
# Requirement already satisfied: numpy in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.25.0)
# Requirement already satisfied: scipy in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.11.1)
# Requirement already satisfied: pandastable in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (0.13.1)
# Requirement already satisfied: matplotlib>=3.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pandastable) (3.7.2)
# Requirement already satisfied: pandas>=1.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pandastable) (2.0.3)
# Requirement already satisfied: numexpr>=2.4 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pandastable) (2.8.4)
# Requirement already satisfied: xlrd>=0.9 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pandastable) (2.0.1)
# Requirement already satisfied: future in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pandastable) (0.18.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0->pandastable) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0->pandastable) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0->pandastable) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0->pandastable) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0->pandastable) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0->pandastable) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0->pandastable) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0->pandastable) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.0->pandastable) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.5->pandastable) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.5->pandastable) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0->pandastable) (1.16.0)

# %% [markdown]
# ## Imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import datetime
import string
import json
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # 1. Crawler Component

# %%
# Define Seed Page
URL = "https://pureportal.coventry.ac.uk/en/organisations/coventry-university/persons/"

# Define profile URL format. This was obtained by manually examining the profile pages
profile_url = "https://pureportal.coventry.ac.uk/en/persons/"

# %% [markdown]
# The seed page, i.e coventry researchers profiles landing page, contains profiles of all academic researchers of the University. As there are up to 2206 results, a limited number are displayed at once (50).
#
# Even if new profiles are added and a new page is required, the crawler will need to crawl through all pages to access every profile. To do this, a function is defined to retrieve the current total number of result pages.

# %%
def get_maximum_page():
    
    first = requests.get(URL)
    soup = BeautifulSoup(first.text, 'html.parser')
    final_page = soup.select('#main-content > div > section > nav > ul > li:nth-child(12) > a')[0]['href']
    fp = final_page.split('=')[-1]
    return int(fp)
    
mx = get_maximum_page()

# %% [markdown]
# Instead of crawling all researchers, this web crawler is designed to specifically find researchers who:
#
# 1. Have research publications
# 2. Are part of the "**School of Computing, Electronics and Maths**"

# %%
def check_department(researcher):
    
    l1 = researcher.find('div', class_='rendering_person_short')
      
    for span in l1.find_all('span'):
        # Check department
        if span.text == str('School of Computing, Electronics and Maths'):
            name = researcher.find('h3', class_='title').find('span').text
            return name
        else:
            pass

# def create_csv():
#     database = pd.DataFrame(columns=['Title', 'Author', 'Published', 'Link'])
#     database.to_csv('database.csv')
    
def update_csv(database):
    current_data = pd.read_csv(database, index_col="Unnamed: 0")
    return current_data        

def enter_each_researchers_publication(researcher, url, df):
    
    new_url = url + str(researcher).replace(' ','-').lower() + '/publications/'
    page = requests.get(new_url)
    soup = BeautifulSoup(page.content, "html.parser")
    results = soup.find(id="main-content")
    papers = results.find_all("li", class_="list-result-item")
    
    
    for paper in papers:
        title = paper.find('h3', class_='title').find('span')
        author = paper.find('a', class_='link person').find('span')
        date = paper.find('span', class_="date")
        link = paper.find('h3', class_='title').find('a', href=True)['href']
        
        opening = pd.read_csv('database.csv', index_col="Unnamed: 0")
        opening = opening.append({'Title': title.text, 
                                  'Author': author.text, 
                                  'Published': date.text,
                                  'Link': link}, ignore_index=True)
        opening.to_csv('database.csv')

# %%
## Scrape function
def scrape(mx):
    df = update_csv('database.csv')
    i=0
    while True:
    
        if i > 17:
            break
            
        if i>0:
            url = URL + '?page=' + str(i)
        else:
            url = URL
    
        i = i+1
        # scraping starts here
        page = requests.get(url)
        soup = BeautifulSoup(page.content, "html.parser")
        results = soup.find(id="main-content")
        researchers = results.find_all("li", class_="grid-result-item")

        for researcher in researchers:
            # Check if researcher has any papers
            check = researcher.find('div', class_='stacked-trend-widget')
            if check:
                name = check_department(researcher)
                if name is None:
                    pass
                else:
                    enter_each_researchers_publication(name, profile_url, df)

# %%
update_csv(database='database.csv') #create_csv

# %time scrape(mx)
# Out:
# CPU times: total: 1.75 s
# Wall time: 45.2 s

# %%
sample_db = pd.read_csv('database.csv').rename(columns={'Unnamed: 0':'SN'})
sample_db
print(f'{sample_db.shape[0]} records were scraped')
# Out:
# 1188 records were scraped

# %% [markdown]
# # 2. Indexing Component

# %%
scraped_db = pd.read_csv('database.csv').rename(columns={'Unnamed: 0':'SN'}).reset_index(drop=True)
scraped_db.head()
# scraped_db = pd.read_csv('database.csv', index_col=0)
# Out:
#    SN                                              Title          Author  \
# 0   0  Cross-Layer Multipath Multichannel MAC protoco...  Abdelshafy, M.
# 1   1  Performance evaluation of Receiver Directed Tr...  Abdelshafy, M.
# 2   2  Reliable Multipath Multi-channel Route Migrati...  Abdelshafy, M.
# 3   3              Resisting blackhole attacks on MANETs  Abdelshafy, M.
# 4   4               Dynamic Source Routing under Attacks  Abdelshafy, M.
#
#      Published                                               Link
# 0     Jun 2018  https://pureportal.coventry.ac.uk/en/publicati...
# 1   4 May 2017  https://pureportal.coventry.ac.uk/en/publicati...
# 2  23 Nov 2017  https://pureportal.coventry.ac.uk/en/publicati...
# 3     Jan 2016  https://pureportal.coventry.ac.uk/en/publicati...
# 4  12 Oct 2015  https://pureportal.coventry.ac.uk/en/publicati...

# %%
sample_db.head(7)
#ids = scraped_db["Title"]
#scraped_db[ids.isin(ids[ids.duplicated()])]
# Out:
#    SN                                              Title          Author  \
# 0   0  Cross-Layer Multipath Multichannel MAC protoco...  Abdelshafy, M.
# 1   1  Performance evaluation of Receiver Directed Tr...  Abdelshafy, M.
# 2   2  Reliable Multipath Multi-channel Route Migrati...  Abdelshafy, M.
# 3   3              Resisting blackhole attacks on MANETs  Abdelshafy, M.
# 4   4               Dynamic Source Routing under Attacks  Abdelshafy, M.
# 5   5  AODV & SAODV under Attack: Performance Comparison  Abdelshafy, M.
# 6   6  AODV Routing Protocol Performance Analysis und...  Abdelshafy, M.
#
#      Published                                               Link
# 0     Jun 2018  https://pureportal.coventry.ac.uk/en/publicati...
# 1   4 May 2017  https://pureportal.coventry.ac.uk/en/publicati...
# 2  23 Nov 2017  https://pureportal.coventry.ac.uk/en/publicati...
# 3     Jan 2016  https://pureportal.coventry.ac.uk/en/publicati...
# 4  12 Oct 2015  https://pureportal.coventry.ac.uk/en/publicati...
# 5     Jun 2014  https://pureportal.coventry.ac.uk/en/publicati...
# 6     Jun 2014  https://pureportal.coventry.ac.uk/en/publicati...

# %%
single_row = scraped_db.loc[1,:].copy()
single_row
# Out:
# SN                                                           1
# Title        Performance evaluation of Receiver Directed Tr...
# Author                                          Abdelshafy, M.
# Published                                           4 May 2017
# Link         https://pureportal.coventry.ac.uk/en/publicati...
# Name: 1, dtype: object

# %% [markdown]
# ## 2.1 Preprocess Text

# %%
# Remove stop words
sw = stopwords.words("english")
lemmatizer = WordNetLemmatizer()




def tp1(txt):
    txt = txt.lower()   # Make lowercase
    txt = txt.translate(str.maketrans('',
                                      '',
                                      string.punctuation))   # Remove punctuation marks
    txt = lematize(txt)
    return txt


def fwpt(word):
    tag = pos_tag([word])[0][1][0].upper()
    hash_tag = {"V": wordnet.VERB, "R": wordnet.ADV,"N": wordnet.NOUN,"J": wordnet.ADJ}         
    return hash_tag.get(tag, wordnet.NOUN)

def lematize(text):
        tkns = nltk.word_tokenize(text)
        ax = ""
        for each in tkns:
            if each not in sw:
                ax += lemmatizer.lemmatize(each, fwpt(each)) + " "
        return ax

# %%
# Sample title
single_row['Title']
# Out:
# 'Performance evaluation of Receiver Directed Transmission protocol with a single transceiver in MANETs'

# %%
# Demonstration of lowercase and punctuation removal
tp1(single_row['Title'])
# Out:
# 'performance evaluation receiver direct transmission protocol single transceiver manet '

# %%
# Demonstration of lematization

lematize(tp1(single_row['Title']))
#lematize(single_row['Title'])
# Out:
# 'performance evaluation receiver direct transmission protocol single transceiver manet '

# %% [markdown]
# #### Unprocessed

# %%
sample_db['Title'].iloc[5]
# Out:
# 'AODV & SAODV under Attack: Performance Comparison'

# %% [markdown]
# #### Processed

# %%
scraped_db['Title'].iloc[5]
# Out:
# 'AODV & SAODV under Attack: Performance Comparison'

# %% [markdown]
# ### 2.1.1 Preprocess entire dataframe

# %%
processed_db = scraped_db.copy()

def preprocess_df(df):
    df.Title = df.Title.apply(tp1)
    df.Author = df.Author.str.lower()
    df = df.drop(columns=['Author','Published'], axis=1)
    return df
    
preprocess_df(processed_db)
processed_db.head()
# Out:
#    SN                                              Title          Author  \
# 0   0  crosslayer multipath multichannel mac protocol...  abdelshafy, m.
# 1   1  performance evaluation receiver direct transmi...  abdelshafy, m.
# 2   2  reliable multipath multichannel route migratio...  abdelshafy, m.
# 3   3                     resist blackhole attack manet   abdelshafy, m.
# 4   4                        dynamic source rout attack   abdelshafy, m.
#
#      Published                                               Link
# 0     Jun 2018  https://pureportal.coventry.ac.uk/en/publicati...
# 1   4 May 2017  https://pureportal.coventry.ac.uk/en/publicati...
# 2  23 Nov 2017  https://pureportal.coventry.ac.uk/en/publicati...
# 3     Jan 2016  https://pureportal.coventry.ac.uk/en/publicati...
# 4  12 Oct 2015  https://pureportal.coventry.ac.uk/en/publicati...

# %% [markdown]
# ## 2.2 Index Construction

# %%
single = processed_db.loc[0,:].copy()
print(single)
indexing_trial = {}

words = single.Title.split()
SN = single.SN
word = words[0]
example = {word: [SN]}

print('=====================================================================')
print('Sample index')
print(example)
# Out:
# SN                                                           0
# Title        crosslayer multipath multichannel mac protocol...
# Author                                          abdelshafy, m.
# Published                                             Jun 2018
# Link         https://pureportal.coventry.ac.uk/en/publicati...
# Name: 0, dtype: object
# =====================================================================
# Sample index
# {'crosslayer': [0]}

# %%
## Indexer Function
def apply_index(inputs, index):
    words = inputs.Title.split()
    SN = int(inputs.SN)
    for word in words:
        if word in index.keys():
            if SN not in index[word]:
                index[word].append(SN)
        else:
            index[word] = [SN]
    return index

indx = apply_index(inputs=single, index= {})
#print(indx)

# %%
def full_index(df, index):
    for x in range(len(df)):
        inpt = df.loc[x,:]
        ind = apply_index(inputs=inpt, index=index)
    return ind

def construct_index(df, index):
    queue = preprocess_df(df)
    ind = full_index(df=queue, index=index)
    return ind

indexed = full_index(processed_db, 
                     index = {})


indexes = construct_index(df=scraped_db, 
                          index = {})

# %%
with open('indexes.json', 'w') as new_f:
    json.dump(indexes, new_f, sort_keys=True, indent=4)
    
with open('indexes.json', 'r') as file:
    data = json.load(file)

def index_2(df, x_path):
    if len(df) > 0:
        with open(x_path, 'r') as file:
            prior_index = json.load(file)
        new_index = construct_index(df = df, index = prior_index)
        with open(x_path, 'w') as new_f:
            json.dump(new_index, new_f, sort_keys=True, indent=4)

# %%
len(data)
# Out:
# 1258

# %%
data
# Out:
# {'10': [111, 377, 507, 773, 903, 1169],
#  '15360bit': [108, 504, 900],
#  '2007': [176, 572, 968],
#  '2009': [371, 767, 1163],
#  '2015': [323, 719, 1115],
#  '30': [224, 225, 620, 621, 1016, 1017],
#  '3dterrains': [96, 492, 888],
#  '40': [252, 648, 1044],
#  '4th': [371, 767, 1163],
#  '81': [111, 377, 507, 773, 903, 1169],
#  'abcsg': [286, 682, 1078],
#  'ability': [248, 644, 1040],
#  'absorption': [106, 502, 898],
#  'acceleration': [29, 425, 821],
#  'access': [66, 462, 858],
#  'accommodation': [178, 190, 574, 586, 970, 982],
#  'accord': [319, 715, 1111],
#  'accurate': [129, 525, 921],
#  'achievementbased': [220, 616, 1012],
#  'action': [242, 368, 638, 764, 1034, 1160],
#  'active': [10, 318, 406, 714, 802, 1110],
#  'activity': [104,
#   105,
#   119,
#   121,
#   198,
#   235,
#   257,
#   334,
#   500,
#   501,
#   515,
#   517,
#   594,
#   631,
#   653,
#   730,
#   896,
#   897,
#   911,
#   913,
#   990,
#   1027,
#   1049,
#   1126],
#  'activityled': [120, 367, 516, 763, 912, 1159],
#  'actuator': [98, 101, 494, 497, 890, 893],
#  'ad': [2, 398, 794],
#  'adapt': [319, 328, 332, 715, 724, 728, 1111, 1120, 1124],
#  'adaptation': [52, 56, 448, 452, 844, 848],
#  'adaptive': [55,
#   102,
#   182,
#   207,
#   214,
#   215,
#   268,
#   312,
#   324,
#   451,
#   498,
#   578,
#   603,
#   610,
#   611,
#   664,
#   708,
#   720,
#   847,
#   894,
#   974,
#   999,
#   1006,
#   1007,
#   1060,
#   1104,
#   1116],
#  'adaptivity': [53, 54, 57, 58, 449, 450, 453, 454, 845, 846, 849, 850],
#  'adolescent': [185,
#   189,
#   192,
#   200,
#   221,
#   581,
#   585,
#   588,
#   596,
#   617,
#   977,
#   981,
#   984,
#   992,
#   1013],
#  'adult': [140, 312, 536, 708, 932, 1104],
#  'advance': [170, 566, 962],
#  'adversarial': [124, 135, 520, 531, 916, 927],
#  'aerospace': [307, 310, 703, 706, 1099, 1102],
#  'affect': [317, 320, 323, 713, 716, 719, 1109, 1112, 1115],
#  'affectaware': [313, 314, 317, 709, 710, 713, 1105, 1106, 1109],
#  'affective': [314,
#   315,
#   316,
#   319,
#   324,
#   330,
#   331,
#   332,
#   710,
#   711,
#   712,
#   715,
#   720,
#   726,
#   727,
#   728,
#   1106,
#   1107,
#   1108,
#   1111,
#   1116,
#   1122,
#   1123,
#   1124],
#  'affine': [95, 491, 887],
#  'agent': [77,
#   174,
#   175,
#   176,
#   236,
#   237,
#   335,
#   370,
#   473,
#   570,
#   571,
#   572,
#   632,
#   633,
#   731,
#   766,
#   869,
#   966,
#   967,
#   968,
#   1028,
#   1029,
#   1127,
#   1162],
#  'agentbased': [61, 79, 457, 475, 853, 871],
#  'agentsbased': [65, 461, 857],
#  'aggregate': [273,
#   287,
#   288,
#   289,
#   291,
#   292,
#   296,
#   669,
#   683,
#   684,
#   685,
#   687,
#   688,
#   692,
#   1065,
#   1079,
#   1080,
#   1081,
#   1083,
#   1084,
#   1088],
#  'aggressive': [265, 661, 1057],
#  'ahvaz': [167, 563, 959],
#  'aint': [318, 714, 1110],
#  'air': [385, 781, 1177],
#  'algorithm': [39,
#   49,
#   128,
#   144,
#   264,
#   266,
#   267,
#   269,
#   270,
#   272,
#   273,
#   276,
#   279,
#   287,
#   375,
#   435,
#   445,
#   524,
#   540,
#   660,
#   662,
#   663,
#   665,
#   666,
#   668,
#   669,
#   672,
#   675,
#   683,
#   771,
#   831,
#   841,
#   920,
#   936,
#   1056,
#   1058,
#   1059,
#   1061,
#   1062,
#   1064,
#   1065,
#   1068,
#   1071,
#   1079,
#   1167],
#  'algorithmbased': [286, 682, 1078],
#  'algorithmsbased': [288, 290, 684, 686, 1080, 1082],
#  'alignment': [119, 515, 911],
#  'allocation': [61, 65, 457, 461, 853, 857],
#  'amadl': [323, 719, 1115],
#  'among': [141, 365, 537, 761, 933, 1157],
#  'amongst': [205, 601, 997],
#  'analogue': [24, 420, 816],
#  'analysis': [6,
#   8,
#   9,
#   87,
#   88,
#   90,
#   101,
#   114,
#   127,
#   147,
#   152,
#   153,
#   155,
#   164,
#   252,
#   306,
#   346,
#   381,
#   402,
#   404,
#   405,
#   483,
#   484,
#   486,
#   497,
#   510,
#   523,
#   543,
#   548,
#   549,
#   551,
#   560,
#   648,
#   702,
#   742,
#   777,
#   798,
#   800,
#   801,
#   879,
#   880,
#   882,
#   893,
#   906,
#   919,
#   939,
#   944,
#   945,
#   947,
#   956,
#   1044,
#   1098,
#   1138,
#   1173],
#  'analytics': [130, 188, 247, 526, 584, 643, 922, 980, 1039],
#  'android': [115, 382, 511, 778, 907, 1174],
#  'annual': [167, 563, 959],
#  'anomaly': [258, 654, 1050],
#  'anxiety': [142, 538, 934],
#  'aodv': [5, 6, 7, 8, 401, 402, 403, 404, 797, 798, 799, 800],
#  'applicability': [384, 780, 1176],
#  'application': [26,
#   29,
#   35,
#   36,
#   110,
#   114,
#   146,
#   148,
#   207,
#   219,
#   223,
#   259,
#   262,
#   263,
#   276,
#   305,
#   307,
#   381,
#   422,
#   425,
#   431,
#   432,
#   506,
#   510,
#   542,
#   544,
#   603,
#   615,
#   619,
#   655,
#   658,
#   659,
#   672,
#   701,
#   703,
#   777,
#   818,
#   821,
#   827,
#   828,
#   902,
#   906,
#   938,
#   940,
#   999,
#   1011,
#   1015,
#   1051,
#   1054,
#   1055,
#   1068,
#   1097,
#   1099,
#   1173],
#  'applications—thermal': [310, 706, 1102],
#  'apply': [264, 272, 660, 668, 1056, 1064],
#  'approach': [66,
#   74,
#   78,
#   79,
#   83,
#   85,
#   89,
#   98,
#   104,
#   105,
#   120,
#   121,
#   125,
#   126,
#   185,
#   189,
#   194,
#   195,
#   203,
#   208,
#   211,
#   220,
#   221,
#   229,
#   294,
#   342,
#   462,
#   470,
#   474,
#   475,
#   479,
#   481,
#   485,
#   494,
#   500,
#   501,
#   516,
#   517,
#   521,
#   522,
#   581,
#   585,
#   590,
#   591,
#   599,
#   604,
#   607,
#   616,
#   617,
#   625,
#   690,
#   738,
#   858,
#   866,
#   870,
#   871,
#   875,
#   877,
#   881,
#   890,
#   896,
#   897,
#   912,
#   913,
#   917,
#   918,
#   977,
#   981,
#   986,
#   987,
#   995,
#   1000,
#   1003,
#   1012,
#   1013,
#   1021,
#   1086,
#   1134],
#  'approximate': [82, 146, 155, 478, 542, 551, 874, 938, 947],
#  'approximation': [156,
#   163,
#   273,
#   287,
#   288,
#   289,
#   291,
#   292,
#   296,
#   552,
#   559,
#   669,
#   683,
#   684,
#   685,
#   687,
#   688,
#   692,
#   948,
#   955,
#   1065,
#   1079,
#   1080,
#   1081,
#   1083,
#   1084,
#   1088],
#  'architecture': [33,
#   63,
#   67,
#   72,
#   238,
#   429,
#   459,
#   463,
#   468,
#   634,
#   825,
#   855,
#   859,
#   864,
#   1030],
#  'arithmetic': [108, 504, 900],
#  'artefact': [111, 377, 507, 773, 903, 1169],
#  'artificial': [95,
#   97,
#   99,
#   279,
#   286,
#   491,
#   493,
#   495,
#   675,
#   682,
#   887,
#   889,
#   891,
#   1071,
#   1078],
#  'assess': [122, 162, 195, 518, 558, 591, 914, 954, 987],
#  'assessment': [119,
#   133,
#   151,
#   220,
#   322,
#   369,
#   515,
#   529,
#   547,
#   616,
#   718,
#   765,
#   911,
#   925,
#   943,
#   1012,
#   1114,
#   1161],
#  'asset': [153, 154, 549, 550, 945, 946],
#  'assist': [362, 758, 1154],
#  'assistive': [229, 625, 1021],
#  'attack': [3,
#   4,
#   5,
#   6,
#   7,
#   8,
#   10,
#   11,
#   172,
#   399,
#   400,
#   401,
#   402,
#   403,
#   404,
#   406,
#   407,
#   568,
#   795,
#   796,
#   797,
#   798,
#   799,
#   800,
#   802,
#   803,
#   964],
#  'attentiongating': [238, 634, 1030],
#  'attitude': [82, 478, 874],
#  'attribute': [184, 580, 976],
#  'auditable': [113, 378, 509, 774, 905, 1170],
#  'auditory': [345, 741, 1137],
#  'audix': [345, 741, 1137],
#  'augment': [308, 704, 1100],
#  'author': [214, 215, 610, 611, 1006, 1007],
#  'autism': [321, 322, 335, 336, 717, 718, 731, 732, 1113, 1114, 1127, 1128],
#  'autistic': [338, 734, 1130],
#  'autoencoder': [235, 631, 1027],
#  'autoencoders': [232, 628, 1024],
#  'automate': [127, 145, 374, 523, 541, 770, 919, 937, 1166],
#  'automaton': [74, 470, 866],
#  'autonomous': [227, 623, 1019],
#  'availability': [44, 49, 164, 440, 445, 560, 836, 841, 956],
#  'avoidance': [100, 496, 892],
#  'awareness': [193, 203, 589, 599, 985, 995],
#  'axial': [354, 750, 1146],
#  'azizdiffie': [11, 407, 803],
#  'background': [340, 736, 1132],
#  'bacterial': [274, 278, 280, 670, 674, 676, 1066, 1070, 1072],
#  'balance': [182, 578, 974],
#  'bar': [83, 85, 87, 88, 89, 479, 481, 483, 484, 485, 875, 877, 879, 880, 881],
#  'base': [24,
#   55,
#   94,
#   176,
#   235,
#   242,
#   247,
#   248,
#   258,
#   260,
#   261,
#   262,
#   265,
#   278,
#   304,
#   324,
#   370,
#   420,
#   451,
#   490,
#   572,
#   631,
#   638,
#   643,
#   644,
#   654,
#   656,
#   657,
#   658,
#   661,
#   674,
#   700,
#   720,
#   766,
#   816,
#   847,
#   886,
#   968,
#   1027,
#   1034,
#   1039,
#   1040,
#   1050,
#   1052,
#   1053,
#   1054,
#   1057,
#   1070,
#   1096,
#   1116,
#   1162],
#  'basis': [144, 156, 364, 540, 552, 760, 936, 948, 1156],
#  'bayesian': [132,
#   146,
#   152,
#   169,
#   171,
#   342,
#   528,
#   542,
#   548,
#   565,
#   567,
#   738,
#   924,
#   938,
#   944,
#   961,
#   963,
#   1134],
#  'bee': [279, 286, 675, 682, 1071, 1078],
#  'behaviour': [131, 300, 317, 363, 527, 696, 713, 759, 923, 1092, 1109, 1155],
#  'behavioural': [130, 183, 526, 579, 922, 975],
#  'bek': [353, 749, 1145],
#  'benefit': [321, 717, 1113],
#  'bgqos': [25, 421, 817],
#  'big': [129, 525, 921],
#  'bioinspired': [276, 284, 672, 680, 1068, 1076],
#  'blackhole': [3, 399, 795],
#  'blasius': [350, 355, 746, 751, 1142, 1147],
#  'board': [180, 576, 972],
#  'bound': [50, 51, 446, 447, 842, 843],
#  'boundary': [143,
#   145,
#   348,
#   350,
#   355,
#   358,
#   539,
#   541,
#   744,
#   746,
#   751,
#   754,
#   935,
#   937,
#   1140,
#   1142,
#   1147,
#   1150],
#  'boundarylayer': [349,
#   351,
#   352,
#   353,
#   354,
#   356,
#   745,
#   747,
#   748,
#   749,
#   750,
#   752,
#   1141,
#   1143,
#   1144,
#   1145,
#   1146,
#   1148],
#  'brain': [198, 594, 990],
#  'breakage': [88, 484, 880],
#  'breakthrough': [160, 556, 952],
#  'bridging': [380, 776, 1172],
#  'broad': [356, 752, 1148],
#  'broken': [83, 85, 87, 89, 479, 481, 483, 485, 875, 877, 879, 881],
#  'building': [122,
#   126,
#   300,
#   363,
#   369,
#   518,
#   522,
#   696,
#   759,
#   765,
#   914,
#   918,
#   1092,
#   1155,
#   1161],
#  'business': [25, 213, 250, 421, 609, 646, 817, 1005, 1042],
#  'cabin': [376, 383, 384, 386, 772, 779, 780, 782, 1168, 1175, 1176, 1178],
#  'calculate': [49, 445, 841],
#  'calibration': [302, 698, 1094],
#  'cap': [14, 410, 806],
#  'car': [384, 385, 386, 780, 781, 782, 1176, 1177, 1178],
#  'carbon': [160, 556, 952],
#  'care': [142, 538, 934],
#  'career': [192, 200, 208, 588, 596, 604, 984, 992, 1000],
#  'carlo': [22, 418, 814],
#  'cascade': [62, 101, 458, 497, 854, 893],
#  'case': [133,
#   192,
#   200,
#   263,
#   282,
#   380,
#   529,
#   588,
#   596,
#   659,
#   678,
#   776,
#   925,
#   984,
#   992,
#   1055,
#   1074,
#   1172],
#  'cclo': [216, 612, 1008],
#  'cdse': [106, 502, 898],
#  'ceiling': [125, 521, 917],
#  'center': [256, 652, 1048],
#  'central': [136, 532, 928],
#  'centrifugal': [354, 750, 1146],
#  'certificateless': [107, 503, 899],
#  'challenge': [159, 216, 371, 555, 612, 767, 951, 1008, 1163],
#  'change': [111,
#   183,
#   187,
#   316,
#   377,
#   507,
#   579,
#   583,
#   712,
#   773,
#   903,
#   975,
#   979,
#   1108,
#   1169],
#  'changepoint': [160, 167, 556, 563, 952, 959],
#  'channel': [12,
#   13,
#   14,
#   15,
#   20,
#   213,
#   347,
#   408,
#   409,
#   410,
#   411,
#   416,
#   609,
#   743,
#   804,
#   805,
#   806,
#   807,
#   812,
#   1005,
#   1139],
#  'character': [297, 693, 1089],
#  'characterisation': [87, 106, 483, 502, 879, 898],
#  'characteristic': [340, 736, 1132],
#  'characterization': [157, 553, 949],
#  'chemoinspired': [273, 669, 1065],
#  'child': [336, 375, 732, 771, 1128, 1167],
#  'chinese': [248, 644, 1040],
#  'chip': [34, 430, 826],
#  'choice': [344, 740, 1136],
#  'circuit': [47, 443, 839],
#  'circular': [122, 126, 518, 522, 914, 918],
#  'city': [134, 530, 926],
#  'classification': [131,
#   145,
#   235,
#   248,
#   268,
#   282,
#   364,
#   527,
#   541,
#   631,
#   644,
#   664,
#   678,
#   760,
#   923,
#   937,
#   1027,
#   1040,
#   1060,
#   1074,
#   1156],
#  'classroom': [206, 211, 333, 602, 607, 729, 998, 1003, 1125],
#  'climate': [159, 374, 555, 770, 951, 1166],
#  'clinical': [128, 524, 920],
#  'cloud': [66, 247, 256, 462, 643, 652, 858, 1039, 1048],
#  'cluster': [268,
#   274,
#   275,
#   276,
#   281,
#   664,
#   670,
#   671,
#   672,
#   677,
#   1060,
#   1066,
#   1067,
#   1068,
#   1073],
#  'cmeans': [276, 672, 1068],
#  'code': [194, 361, 590, 757, 986, 1153],
#  'codesign': [373, 769, 1165],
#  'cognitive': [313, 709, 1105],
#  'coherent': [204, 600, 996],
#  'cold': [133, 529, 925],
#  'collaboration': [213, 609, 1005],
#  'collaborative': [92,
#   103,
#   120,
#   216,
#   365,
#   370,
#   488,
#   499,
#   516,
#   612,
#   761,
#   766,
#   884,
#   895,
#   912,
#   1008,
#   1157,
#   1162],
#  'collapse': [47, 443, 839],
#  'collective': [226, 622, 1018],
#  'colliculus': [239, 635, 1031],
#  'colony': [279, 286, 675, 682, 1071, 1078],
#  'combination': [281, 677, 1073],
#  'comfort': [376, 384, 385, 386, 772, 780, 781, 782, 1168, 1176, 1177, 1178],
#  'common': [297, 693, 1089],
#  'communicate': [372, 768, 1164],
#  'communication': [13,
#   15,
#   18,
#   19,
#   20,
#   22,
#   23,
#   24,
#   409,
#   411,
#   414,
#   415,
#   416,
#   418,
#   419,
#   420,
#   805,
#   807,
#   810,
#   811,
#   812,
#   814,
#   815,
#   816],
#  'community': [213, 245, 249, 609, 641, 645, 1005, 1037, 1041],
#  'communitybased': [251, 254, 647, 650, 1043, 1046],
#  'companion': [234, 630, 1026],
#  'comparative': [275, 671, 1067],
#  'comparison': [5, 82, 118, 401, 478, 514, 797, 874, 910],
#  'complexity': [226, 622, 1018],
#  'component': [86, 88, 122, 126, 482, 484, 518, 522, 878, 880, 914, 918],
#  'composition': [71, 467, 863],
#  'compressible': [356, 752, 1148],
#  'compression': [103, 499, 895],
#  'computational': [106,
#   137,
#   151,
#   370,
#   502,
#   533,
#   547,
#   766,
#   898,
#   929,
#   943,
#   1162],
#  'compute': [247,
#   252,
#   367,
#   371,
#   373,
#   643,
#   648,
#   763,
#   767,
#   769,
#   1039,
#   1044,
#   1159,
#   1163,
#   1165],
#  'computer': [57, 120, 453, 516, 849, 912],
#  'concealment': [73, 469, 865],
#  'concept': [328, 724, 1120],
#  'concern': [263, 659, 1055],
#  'concrete': [389, 785, 1181],
#  'conditioning': [385, 781, 1177],
#  'cone': [354, 356, 750, 752, 1146, 1148],
#  'configuration': [250, 646, 1042],
#  'consideration': [137, 533, 929],
#  'constrain': [95, 99, 491, 495, 887, 891],
#  'constraint': [96, 100, 492, 496, 888, 892],
#  'construct': [132, 528, 924],
#  'construction': [107, 503, 899],
#  'constructive': [119, 318, 515, 714, 911, 1110],
#  'consumption': [50, 258, 446, 654, 842, 1050],
#  'contactors': [160, 556, 952],
#  'content': [75, 196, 291, 471, 592, 687, 867, 988, 1083],
#  'contest': [176, 572, 968],
#  'continuous': [303, 699, 1095],
#  'contribute': [332, 728, 1124],
#  'control': [82,
#   95,
#   97,
#   99,
#   103,
#   374,
#   376,
#   385,
#   386,
#   478,
#   491,
#   493,
#   495,
#   499,
#   770,
#   772,
#   781,
#   782,
#   874,
#   887,
#   889,
#   891,
#   895,
#   1166,
#   1168,
#   1177,
#   1178],
#  'controller': [102, 498, 894],
#  'convey': [187, 583, 979],
#  'convolutional': [32, 232, 428, 628, 824, 1024],
#  'cool': [300, 363, 696, 759, 1092, 1155],
#  'coordinatefree': [82, 478, 874],
#  'copula': [149, 155, 156, 545, 551, 552, 941, 947, 948],
#  'copulabased': [133, 529, 925],
#  'corporate': [112, 508, 904],
#  'correction': [31, 427, 823],
#  'corrosion': [389, 391, 394, 395, 785, 787, 790, 791, 1181, 1183, 1186, 1187],
#  'cortex': [240, 636, 1032],
#  'cost': [129, 525, 921],
#  'counterdiscriminator': [41, 437, 833],
#  'couple': [162, 168, 265, 295, 558, 564, 661, 691, 954, 960, 1057, 1087],
#  'coventry': [263, 659, 1055],
#  'covid19': [125, 128, 141, 142, 521, 524, 537, 538, 917, 920, 933, 934],
#  'cps': [247, 643, 1039],
#  'create': [204, 600, 996],
#  'creative': [367, 387, 763, 783, 1159, 1179],
#  'crime': [147, 543, 939],
#  'critical': [82, 262, 478, 658, 874, 1054],
#  'cross': [124, 520, 916],
#  'crosslayer': [0, 396, 792],
#  'cultural': [205, 601, 997],
#  'curiosity': [387, 783, 1179],
#  'current': [86, 482, 878],
#  'curve': [110, 359, 506, 755, 902, 1151],
#  'customer': [388, 784, 1180],
#  'cyclist': [227, 228, 623, 624, 1019, 1020],
#  'data': [42,
#   43,
#   48,
#   73,
#   80,
#   129,
#   132,
#   147,
#   186,
#   188,
#   226,
#   228,
#   247,
#   256,
#   258,
#   271,
#   272,
#   274,
#   275,
#   286,
#   323,
#   343,
#   438,
#   439,
#   444,
#   469,
#   476,
#   525,
#   528,
#   543,
#   582,
#   584,
#   622,
#   624,
#   643,
#   652,
#   654,
#   667,
#   668,
#   670,
#   671,
#   682,
#   719,
#   739,
#   834,
#   835,
#   840,
#   865,
#   872,
#   921,
#   924,
#   939,
#   978,
#   980,
#   1018,
#   1020,
#   1039,
#   1048,
#   1050,
#   1063,
#   1064,
#   1066,
#   1067,
#   1078,
#   1115,
#   1135],
#  'database': [81, 295, 343, 344, 477, 691, 739, 740, 873, 1087, 1135, 1136],
#  'databased': [224, 225, 620, 621, 1016, 1017],
#  'datacentric': [250, 646, 1042],
#  'dcoofdm': [15, 411, 807],
#  'decision': [77, 165, 166, 181, 473, 561, 562, 577, 869, 957, 958, 973],
#  'decisionmaking': [128, 524, 920],
#  'deep': [24,
#   131,
#   229,
#   230,
#   231,
#   232,
#   233,
#   235,
#   246,
#   367,
#   420,
#   527,
#   625,
#   626,
#   627,
#   628,
#   629,
#   631,
#   642,
#   763,
#   816,
#   923,
#   1021,
#   1022,
#   1023,
#   1024,
#   1025,
#   1027,
#   1038,
#   1159],
#  'deficit': [322, 718, 1114],
#  'define': [217, 613, 1009],
#  'delayed': [195, 591, 987],
#  'demand': [313, 709, 1105],
#  'demanddriven': [250, 646, 1042],
#  'demapstaffordshire': [388, 784, 1180],
#  'democratise': [226, 622, 1018],
#  'demonstration': [23, 243, 419, 639, 815, 1035],
#  'depression': [140, 142, 536, 538, 932, 934],
#  'derive': [149, 545, 941],
#  'design': [24,
#   46,
#   55,
#   78,
#   79,
#   120,
#   184,
#   191,
#   197,
#   202,
#   312,
#   336,
#   338,
#   361,
#   371,
#   387,
#   420,
#   442,
#   451,
#   474,
#   475,
#   516,
#   580,
#   587,
#   593,
#   598,
#   708,
#   732,
#   734,
#   757,
#   767,
#   783,
#   816,
#   838,
#   847,
#   870,
#   871,
#   912,
#   976,
#   983,
#   989,
#   994,
#   1104,
#   1128,
#   1130,
#   1153,
#   1163,
#   1179],
#  'detection': [83,
#   86,
#   160,
#   167,
#   227,
#   228,
#   245,
#   258,
#   389,
#   391,
#   392,
#   393,
#   394,
#   395,
#   479,
#   482,
#   556,
#   563,
#   623,
#   624,
#   641,
#   654,
#   785,
#   787,
#   788,
#   789,
#   790,
#   791,
#   875,
#   878,
#   952,
#   959,
#   1019,
#   1020,
#   1037,
#   1050,
#   1181,
#   1183,
#   1184,
#   1185,
#   1186,
#   1187],
#  'detector': [43, 439, 835],
#  'deteriorate': [153, 154, 549, 550, 945, 946],
#  'determine': [279, 675, 1071],
#  'develop': [122,
#   126,
#   128,
#   183,
#   205,
#   335,
#   336,
#   518,
#   522,
#   524,
#   579,
#   601,
#   731,
#   732,
#   914,
#   918,
#   920,
#   975,
#   997,
#   1127,
#   1128],
#  'developer': [365, 761, 1157],
#  'development': [70,
#   84,
#   104,
#   105,
#   119,
#   191,
#   211,
#   213,
#   259,
#   261,
#   365,
#   368,
#   466,
#   480,
#   500,
#   501,
#   515,
#   587,
#   607,
#   609,
#   655,
#   657,
#   761,
#   764,
#   862,
#   876,
#   896,
#   897,
#   911,
#   983,
#   1003,
#   1005,
#   1051,
#   1053,
#   1157,
#   1160],
#  'device': [115, 204, 382, 511, 600, 778, 907, 996, 1174],
#  'dhp': [110, 506, 902],
#  'dhtbased': [68, 464, 860],
#  'diagnosis': [85, 87, 89, 364, 481, 483, 485, 760, 877, 879, 881, 1156],
#  'diagram': [340, 736, 1132],
#  'differ': [313, 709, 1105],
#  'different': [291, 687, 1083],
#  'differential': [267,
#   274,
#   278,
#   281,
#   287,
#   291,
#   663,
#   670,
#   674,
#   677,
#   683,
#   687,
#   1059,
#   1066,
#   1070,
#   1073,
#   1079,
#   1083],
#  'difficulty': [182, 578, 974],
#  'digital': [36,
#   42,
#   43,
#   112,
#   113,
#   119,
#   134,
#   192,
#   200,
#   205,
#   378,
#   432,
#   438,
#   439,
#   508,
#   509,
#   515,
#   530,
#   588,
#   596,
#   601,
#   774,
#   828,
#   834,
#   835,
#   904,
#   905,
#   911,
#   926,
#   984,
#   992,
#   997,
#   1170],
#  'dihedral': [244, 640, 1036],
#  'dimensionality': [264, 267, 295, 660, 663, 691, 1056, 1059, 1087],
#  'direct': [1, 397, 793],
#  'discovery': [249, 645, 1041],
#  'discrete': [148, 265, 544, 661, 940, 1057],
#  'discretization': [270, 666, 1062],
#  'discrimination': [36,
#   37,
#   38,
#   39,
#   48,
#   345,
#   432,
#   433,
#   434,
#   435,
#   444,
#   741,
#   828,
#   829,
#   830,
#   831,
#   840,
#   1137],
#  'disease': [139, 364, 535, 760, 931, 1156],
#  'disk': [349, 357, 358, 359, 745, 753, 754, 755, 1141, 1149, 1150, 1151],
#  'disorder': [321, 322, 335, 717, 718, 731, 1113, 1114, 1127],
#  'display': [340, 342, 343, 736, 738, 739, 1132, 1134, 1135],
#  'distance': [272,
#   278,
#   279,
#   280,
#   281,
#   283,
#   286,
#   290,
#   297,
#   298,
#   668,
#   674,
#   675,
#   676,
#   677,
#   679,
#   682,
#   686,
#   693,
#   694,
#   1064,
#   1070,
#   1071,
#   1072,
#   1073,
#   1075,
#   1078,
#   1082,
#   1089,
#   1090],
#  'distribute': [72, 73, 249, 366, 468, 469, 645, 762, 864, 865, 1041, 1158],
#  'distribution': [148,
#   154,
#   156,
#   163,
#   303,
#   544,
#   550,
#   552,
#   559,
#   699,
#   940,
#   946,
#   948,
#   955,
#   1095],
#  'disturbance': [141, 359, 537, 755, 933, 1151],
#  'diver': [24, 420, 816],
#  'diversity': [14, 15, 16, 19, 410, 411, 412, 415, 806, 807, 808, 811],
#  'dlp': [110, 506, 902],
#  'dna': [274, 670, 1066],
#  'document': [80, 346, 476, 742, 872, 1138],
#  'domain': [48, 444, 840],
#  'dribble': [175, 571, 967],
#  'drive': [127, 523, 919],
#  'driven': [70, 385, 466, 781, 862, 1177],
#  'dual': [82, 131, 478, 527, 874, 923],
#  'dualcareer': [179, 575, 971],
#  'due': [356, 357, 752, 753, 1148, 1149],
#  'duration': [125, 133, 521, 529, 917, 925],
#  'dynamic': [4,
#   12,
#   13,
#   65,
#   101,
#   188,
#   256,
#   400,
#   408,
#   409,
#   461,
#   497,
#   584,
#   652,
#   796,
#   804,
#   805,
#   857,
#   893,
#   980,
#   1048],
#  'early': [21, 149, 417, 545, 813, 941],
#  'ebusiness': [255, 651, 1047],
#  'ecommerce': [218, 614, 1010],
#  'economic': [122, 518, 914],
#  'economy': [122, 126, 518, 522, 914, 918],
#  'edge': [301, 697, 1093],
#  'edit': [283, 290, 297, 298, 679, 686, 693, 694, 1075, 1082, 1089, 1090],
#  'editorial': [255, 651, 1047],
#  'education': [184, 211, 236, 580, 607, 632, 976, 1003, 1028],
#  'educational': [186, 224, 225, 582, 620, 621, 978, 1016, 1017],
#  'effect': [318,
#   340,
#   344,
#   351,
#   355,
#   714,
#   736,
#   740,
#   747,
#   751,
#   1110,
#   1132,
#   1136,
#   1143,
#   1147],
#  'effectiveness': [53, 449, 845],
#  'efficiency': [183, 579, 975],
#  'efficient': [108, 504, 900],
#  'elearning': [53,
#   54,
#   55,
#   58,
#   62,
#   75,
#   449,
#   450,
#   451,
#   454,
#   458,
#   471,
#   845,
#   846,
#   847,
#   850,
#   854,
#   867],
#  'elearninglearning': [210, 606, 1002],
#  'electrical': [86, 90, 482, 486, 878, 882],
#  'electromagnetic': [389, 785, 1181],
#  'element': [183, 362, 579, 758, 975, 1154],
#  'elementary': [333, 729, 1125],
#  'elicitation': [152, 181, 548, 577, 944, 973],
#  'elliptic': [110, 506, 902],
#  'embed': [143, 216, 246, 539, 612, 642, 935, 1008, 1038],
#  'embody': [335, 731, 1127],
#  'embolism': [125, 521, 917],
#  'emergency': [21, 417, 813],
#  'emergent': [238, 634, 1030],
#  'emotion': [229,
#   232,
#   233,
#   234,
#   237,
#   625,
#   628,
#   629,
#   630,
#   633,
#   1021,
#   1024,
#   1025,
#   1026,
#   1029],
#  'emotional': [236, 632, 1028],
#  'empirical': [52, 448, 844],
#  'employ': [332, 728, 1124],
#  'empowerment': [216, 612, 1008],
#  'enact': [185, 581, 977],
#  'encapsulate': [222, 618, 1014],
#  'encode': [269, 665, 1061],
#  'end': [367, 763, 1159],
#  'energy': [183, 258, 300, 363, 579, 654, 696, 759, 975, 1050, 1092, 1155],
#  'energyefficiency': [256, 652, 1048],
#  'enforce': [354, 750, 1146],
#  'engagement': [213,
#   314,
#   362,
#   387,
#   609,
#   710,
#   758,
#   783,
#   1005,
#   1106,
#   1154,
#   1179],
#  'engine': [219, 307, 309, 310, 615, 703, 705, 706, 1011, 1099, 1101, 1102],
#  'engineering': [78, 79, 474, 475, 870, 871],
#  'enhance': [292, 314, 688, 710, 1084, 1106],
#  'enhancement': [59, 375, 455, 771, 851, 1167],
#  'enough': [87, 483, 879],
#  'ensurvival': [178, 574, 970],
#  'entrepreneurship': [179, 575, 971],
#  'environment': [26,
#   68,
#   91,
#   93,
#   94,
#   115,
#   198,
#   218,
#   224,
#   225,
#   320,
#   327,
#   368,
#   382,
#   384,
#   422,
#   464,
#   487,
#   489,
#   490,
#   511,
#   594,
#   614,
#   620,
#   621,
#   716,
#   723,
#   764,
#   778,
#   780,
#   818,
#   860,
#   883,
#   885,
#   886,
#   907,
#   990,
#   1010,
#   1016,
#   1017,
#   1112,
#   1119,
#   1160,
#   1174,
#   1176],
#  'environmental': [178,
#   190,
#   201,
#   308,
#   574,
#   586,
#   597,
#   704,
#   970,
#   982,
#   993,
#   1100],
#  'episode': [133, 529, 925],
#  'equivalence': [110, 506, 902],
#  'equivalent': [383, 385, 779, 781, 1175, 1177],
#  'erst': [341, 737, 1133],
#  'essential': [184, 580, 976],
#  'estimate': [383, 385, 779, 781, 1175, 1177],
#  'estimation': [82, 227, 478, 623, 874, 1019],
#  'ethnographically': [370, 766, 1162],
#  'evaluation': [1,
#   9,
#   45,
#   50,
#   51,
#   52,
#   53,
#   55,
#   84,
#   145,
#   152,
#   195,
#   224,
#   225,
#   268,
#   312,
#   341,
#   397,
#   405,
#   441,
#   446,
#   447,
#   448,
#   449,
#   451,
#   480,
#   541,
#   548,
#   591,
#   620,
#   621,
#   664,
#   708,
#   737,
#   793,
#   801,
#   837,
#   842,
#   843,
#   844,
#   845,
#   847,
#   876,
#   937,
#   944,
#   987,
#   1016,
#   1017,
#   1060,
#   1104,
#   1133],
#  'evapotranspiration': [158, 554, 950],
#  'everand': [194, 590, 986],
#  'everyday': [337, 733, 1129],
#  'evidencebased': [189, 585, 981],
#  'evolution': [267,
#   274,
#   278,
#   287,
#   291,
#   663,
#   670,
#   674,
#   683,
#   687,
#   1059,
#   1066,
#   1070,
#   1079,
#   1083],
#  'evolutionary': [77, 473, 869],
#  'evolutionbased': [281, 677, 1073],
#  'evoting': [67, 71, 463, 467, 859, 863],
#  'examine': [112, 508, 904],
#  'exchange': [163, 213, 365, 559, 609, 761, 955, 1005, 1157],
#  'exercise': [138, 345, 534, 741, 930, 1137],
#  'exhibition': [311, 707, 1103],
#  'expensive': [284, 680, 1076],
#  'experience': [159,
#   177,
#   207,
#   210,
#   213,
#   338,
#   360,
#   555,
#   573,
#   603,
#   606,
#   609,
#   734,
#   756,
#   951,
#   969,
#   999,
#   1002,
#   1005,
#   1130,
#   1152],
#  'experimental': [268, 664, 1060],
#  'exploration': [91, 94, 329, 487, 490, 725, 883, 886, 1121],
#  'exploratory': [316, 320, 327, 712, 716, 723, 1108, 1112, 1119],
#  'explore': [315,
#   316,
#   320,
#   328,
#   329,
#   333,
#   711,
#   712,
#   716,
#   724,
#   725,
#   729,
#   1107,
#   1108,
#   1112,
#   1120,
#   1121,
#   1125],
#  'exponential': [148, 544, 940],
#  'expression': [229,
#   230,
#   231,
#   232,
#   234,
#   275,
#   625,
#   626,
#   627,
#   628,
#   630,
#   671,
#   1021,
#   1022,
#   1023,
#   1024,
#   1026,
#   1067],
#  'extend': [283, 297, 298, 679, 693, 694, 1075, 1089, 1090],
#  'extension': [27, 423, 819],
#  'external': [315, 341, 711, 737, 1107, 1133],
#  'externalize': [220, 616, 1012],
#  'extraction': [83, 86, 366, 479, 482, 762, 875, 878, 1158],
#  'face': [141, 233, 537, 629, 933, 1025],
#  'facial': [229,
#   230,
#   231,
#   232,
#   234,
#   625,
#   626,
#   627,
#   628,
#   630,
#   1021,
#   1022,
#   1023,
#   1024,
#   1026],
#  'facilitate': [196, 592, 988],
#  'factorization': [246, 249, 254, 642, 645, 650, 1038, 1041, 1046],
#  'fading': [14, 410, 806],
#  'failure': [49, 445, 841],
#  'family': [353, 749, 1145],
#  'fast': [293, 689, 1085],
#  'fastanddirty': [295, 691, 1087],
#  'faster': [296, 692, 1088],
#  'fatigue': [138, 534, 930],
#  'fault': [47, 86, 90, 443, 482, 486, 839, 878, 882],
#  'feature': [184, 580, 976],
#  'feed': [149, 545, 941],
#  'feedback': [204,
#   220,
#   312,
#   314,
#   317,
#   319,
#   320,
#   324,
#   327,
#   330,
#   331,
#   600,
#   616,
#   708,
#   710,
#   713,
#   715,
#   716,
#   720,
#   723,
#   726,
#   727,
#   996,
#   1012,
#   1104,
#   1106,
#   1109,
#   1111,
#   1112,
#   1116,
#   1119,
#   1122,
#   1123],
#  'fem': [85, 89, 90, 481, 485, 486, 877, 881, 882],
#  'field': [305, 701, 1097],
#  'fieldmap': [305, 701, 1097],
#  'file': [66, 68, 462, 464, 858, 860],
#  'filter': [82, 293, 295, 478, 689, 691, 874, 1085, 1087],
#  'filterbased': [38, 434, 830],
#  'financial': [146, 150, 542, 546, 938, 942],
#  'first': [136, 367, 532, 763, 928, 1159],
#  'fit': [37, 433, 829],
#  'flat': [352, 748, 1144],
#  'flexible': [250, 260, 269, 646, 656, 665, 1042, 1052, 1061],
#  'flood': [7, 157, 403, 553, 799, 949],
#  'flow': [143,
#   349,
#   350,
#   351,
#   352,
#   353,
#   354,
#   356,
#   357,
#   359,
#   539,
#   745,
#   746,
#   747,
#   748,
#   749,
#   750,
#   752,
#   753,
#   755,
#   935,
#   1141,
#   1142,
#   1143,
#   1144,
#   1145,
#   1146,
#   1148,
#   1149,
#   1151],
#  'flow—exact': [347, 743, 1139],
#  'fluid': [348,
#   353,
#   357,
#   358,
#   359,
#   744,
#   749,
#   753,
#   754,
#   755,
#   1140,
#   1145,
#   1149,
#   1150,
#   1151],
#  'flux': [83, 88, 90, 176, 479, 484, 486, 572, 875, 880, 882, 968],
#  'focus': [201, 597, 993],
#  'fog': [247, 252, 253, 299, 643, 648, 649, 695, 1039, 1044, 1045, 1091],
#  'forage': [274, 278, 280, 670, 674, 676, 1066, 1070, 1072],
#  'forensic': [111, 114, 377, 381, 507, 510, 773, 777, 903, 906, 1169, 1173],
#  'forensics': [112, 113, 119, 378, 508, 509, 515, 774, 904, 905, 911, 1170],
#  'formal': [78, 474, 870],
#  'foster': [197, 312, 593, 708, 989, 1104],
#  'foundation': [188, 584, 980],
#  'fourier': [85, 481, 877],
#  'fpga': [30, 31, 426, 427, 822, 823],
#  'fpgabased': [29, 35, 425, 431, 821, 827],
#  'fpgacpu': [34, 430, 826],
#  'fraction': [318, 327, 328, 714, 723, 724, 1110, 1119, 1120],
#  'framework': [122,
#   126,
#   151,
#   191,
#   219,
#   257,
#   305,
#   518,
#   522,
#   547,
#   587,
#   615,
#   653,
#   701,
#   914,
#   918,
#   943,
#   983,
#   1011,
#   1049,
#   1097],
#  'free': [354, 750, 1146],
#  'frequency': [24,
#   48,
#   83,
#   86,
#   297,
#   420,
#   444,
#   479,
#   482,
#   693,
#   816,
#   840,
#   875,
#   878,
#   1089],
#  'friend': [251, 254, 647, 650, 1043, 1046],
#  'frontend': [81, 477, 873],
#  'frontline': [142, 538, 934],
#  'fso': [19, 415, 811],
#  'function': [144, 149, 156, 364, 540, 545, 552, 760, 936, 941, 948, 1156],
#  'functional': [136, 532, 928],
#  'future': [130, 255, 369, 526, 651, 765, 922, 1047, 1161],
#  'fuzzy': [276, 672, 1068],
#  'game': [177,
#   178,
#   179,
#   180,
#   182,
#   184,
#   185,
#   187,
#   190,
#   191,
#   192,
#   193,
#   196,
#   197,
#   198,
#   199,
#   200,
#   201,
#   202,
#   205,
#   206,
#   207,
#   209,
#   210,
#   211,
#   214,
#   215,
#   217,
#   219,
#   220,
#   222,
#   223,
#   372,
#   387,
#   573,
#   574,
#   575,
#   576,
#   578,
#   580,
#   581,
#   583,
#   586,
#   587,
#   588,
#   589,
#   592,
#   593,
#   594,
#   595,
#   596,
#   597,
#   598,
#   601,
#   602,
#   603,
#   605,
#   606,
#   607,
#   610,
#   611,
#   613,
#   615,
#   616,
#   618,
#   619,
#   768,
#   783,
#   969,
#   970,
#   971,
#   972,
#   974,
#   976,
#   977,
#   979,
#   982,
#   983,
#   984,
#   985,
#   988,
#   989,
#   990,
#   991,
#   992,
#   993,
#   994,
#   997,
#   998,
#   999,
#   1001,
#   1002,
#   1003,
#   1006,
#   1007,
#   1009,
#   1011,
#   1012,
#   1014,
#   1015,
#   1164,
#   1179],
#  'gamebased': [189,
#   194,
#   195,
#   203,
#   208,
#   221,
#   585,
#   590,
#   591,
#   599,
#   604,
#   617,
#   981,
#   986,
#   987,
#   995,
#   1000,
#   1013],
#  'gamer': [360, 756, 1152],
#  'gamified': [183, 579, 975],
#  'gamma': [36, 38, 39, 41, 432, 434, 435, 437, 828, 830, 831, 833],
#  'gas': [306, 307, 309, 310, 702, 703, 705, 706, 1098, 1099, 1101, 1102],
#  'gateway': [253, 299, 649, 695, 1045, 1091],
#  'gaussian': [82,
#   127,
#   145,
#   149,
#   164,
#   478,
#   523,
#   541,
#   545,
#   560,
#   874,
#   919,
#   937,
#   941,
#   956],
#  'gdpr': [112, 508, 904],
#  'gene': [132, 275, 528, 671, 924, 1067],
#  'general': [44, 440, 836],
#  'generalise': [357, 753, 1149],
#  'generalization': [248, 644, 1040],
#  'generalizedgamma': [14, 410, 806],
#  'generation': [47, 124, 135, 172, 443, 520, 531, 568, 839, 916, 927, 964],
#  'generative': [124, 135, 240, 520, 531, 636, 916, 927, 1032],
#  'generic': [107, 503, 899],
#  'genetic': [144,
#   266,
#   269,
#   270,
#   272,
#   273,
#   279,
#   287,
#   288,
#   290,
#   540,
#   662,
#   665,
#   666,
#   668,
#   669,
#   675,
#   683,
#   684,
#   686,
#   936,
#   1058,
#   1061,
#   1062,
#   1064,
#   1065,
#   1071,
#   1079,
#   1080,
#   1082],
#  'geodesic': [96, 492, 888],
#  'geometrybased': [20, 416, 812],
#  'global': [226, 622, 1018],
#  'go': [333, 729, 1125],
#  'gradient': [33, 429, 825],
#  'gram': [286, 682, 1078],
#  'graph': [252, 648, 1044],
#  'graphbased': [316, 712, 1108],
#  'graphical': [343, 739, 1135],
#  'gratification': [195, 591, 987],
#  'greencu': [190, 586, 982],
#  'grid': [25, 26, 421, 422, 817, 818],
#  'gridenabled': [72, 468, 864],
#  'gridsim': [27, 423, 819],
#  'group': [121, 244, 517, 640, 913, 1036],
#  'growth': [149, 201, 545, 597, 941, 993],
#  'gsm': [116, 512, 908],
#  'guidance': [192, 200, 208, 221, 588, 596, 604, 617, 984, 992, 1000, 1013],
#  'guide': [220, 616, 1012],
#  'haar': [271, 667, 1063],
#  'handle': [284, 680, 1076],
#  'hardware': [32, 428, 824],
#  'headlight': [12, 408, 804],
#  'health': [180, 576, 972],
#  'healthcare': [142, 223, 538, 619, 934, 1015],
#  'healthy': [185, 581, 977],
#  'heart': [364, 760, 1156],
#  'heat': [348, 350, 744, 746, 1140, 1142],
#  'heating': [385, 781, 1177],
#  'helicopter': [103, 499, 895],
#  'help': [343, 739, 1135],
#  'herbert': [212, 608, 1004],
#  'heterogeneous': [30,
#   31,
#   32,
#   34,
#   173,
#   426,
#   427,
#   428,
#   430,
#   569,
#   822,
#   823,
#   824,
#   826,
#   965],
#  'hierarchical': [274, 670, 1066],
#  'high': [26, 184, 422, 580, 818, 976],
#  'highfidelity': [219, 615, 1011],
#  'highly': [129, 525, 921],
#  'hisql': [81, 477, 873],
#  'histogram': [33, 429, 825],
#  'historical': [81, 477, 873],
#  'hoc': [2, 398, 794],
#  'human': [235, 362, 631, 758, 1027, 1154],
#  'humanrobotic': [237, 633, 1029],
#  'humid': [159, 555, 951],
#  'hvac': [385, 781, 1177],
#  'hybrid': [63,
#   64,
#   229,
#   237,
#   240,
#   274,
#   278,
#   459,
#   460,
#   625,
#   633,
#   636,
#   670,
#   674,
#   855,
#   856,
#   1021,
#   1029,
#   1032,
#   1066,
#   1070],
#  'hybridization': [280, 676, 1072],
#  'hydraulic': [302, 698, 1094],
#  'hydrometric': [167, 563, 959],
#  'hypermedia': [207, 603, 999],
#  'ict': [312, 708, 1104],
#  'idea': [336, 338, 732, 734, 1128, 1130],
#  'identification': [145, 541, 937],
#  'identitybased': [107, 503, 899],
#  'ii': [272, 668, 1064],
#  'illumination': [230, 626, 1022],
#  'illusion': [285, 681, 1077],
#  'image': [28,
#   29,
#   35,
#   103,
#   234,
#   424,
#   425,
#   431,
#   499,
#   630,
#   820,
#   821,
#   827,
#   895,
#   1026],
#  'imbalanced': [248, 644, 1040],
#  'immigrant': [205, 601, 997],
#  'impact': [12,
#   57,
#   69,
#   138,
#   158,
#   313,
#   320,
#   330,
#   331,
#   408,
#   453,
#   465,
#   534,
#   554,
#   709,
#   716,
#   726,
#   727,
#   804,
#   849,
#   861,
#   930,
#   950,
#   1105,
#   1112,
#   1122,
#   1123],
#  'implement': [159, 182, 213, 375, 555, 578, 609, 771, 951, 974, 1005, 1167],
#  'implementation': [46, 76, 250, 442, 472, 646, 838, 868, 1042],
#  'implication': [111,
#   223,
#   361,
#   377,
#   507,
#   619,
#   757,
#   773,
#   903,
#   1015,
#   1153,
#   1169],
#  'important': [264, 660, 1056],
#  'imprecise': [152, 548, 944],
#  'improve': [34,
#   248,
#   249,
#   302,
#   314,
#   317,
#   379,
#   430,
#   644,
#   645,
#   698,
#   710,
#   713,
#   775,
#   826,
#   1040,
#   1041,
#   1094,
#   1106,
#   1109,
#   1171],
#  'improvement': [40, 102, 436, 498, 832, 894],
#  'incidental': [204, 600, 996],
#  'inclined': [352, 748, 1144],
#  'incomplete': [171, 567, 963],
#  'increase': [188, 584, 980],
#  'index': [163, 277, 559, 673, 955, 1069],
#  'indicator': [204, 600, 996],
#  'individual': [328, 724, 1120],
#  'indonesian': [300, 363, 696, 759, 1092, 1155],
#  'indoor': [16, 18, 412, 414, 808, 810],
#  'induction': [83,
#   85,
#   86,
#   88,
#   89,
#   90,
#   479,
#   481,
#   482,
#   484,
#   485,
#   486,
#   875,
#   877,
#   878,
#   880,
#   881,
#   882],
#  'industry': [252, 648, 1044],
#  'infant': [149, 545, 941],
#  'inferior': [239, 635, 1031],
#  'influence': [183, 579, 975],
#  'inform': [370, 766, 1162],
#  'information': [64,
#   118,
#   144,
#   146,
#   157,
#   162,
#   165,
#   166,
#   168,
#   291,
#   312,
#   340,
#   342,
#   365,
#   366,
#   368,
#   460,
#   514,
#   540,
#   542,
#   553,
#   558,
#   561,
#   562,
#   564,
#   687,
#   708,
#   736,
#   738,
#   761,
#   762,
#   764,
#   856,
#   910,
#   936,
#   938,
#   949,
#   954,
#   957,
#   958,
#   960,
#   1083,
#   1104,
#   1132,
#   1134,
#   1157,
#   1158,
#   1160],
#  'informationbased': [386, 782, 1178],
#  'informationcontent': [289, 685, 1081],
#  'infrastructure': [153, 549, 945],
#  'innovation': [213, 609, 1005],
#  'inpatient': [125, 128, 521, 524, 917, 920],
#  'inquirybased': [177, 197, 202, 573, 593, 598, 969, 989, 994],
#  'inquisition': [304, 700, 1096],
#  'insomnia': [123, 519, 915],
#  'instability': [349, 354, 745, 750, 1141, 1146],
#  'instancetransfer': [248, 644, 1040],
#  'instruction': [243, 639, 1035],
#  'instrumentation': [310, 706, 1102],
#  'integrate': [151,
#   206,
#   207,
#   209,
#   210,
#   243,
#   547,
#   602,
#   603,
#   605,
#   606,
#   639,
#   943,
#   998,
#   999,
#   1001,
#   1002,
#   1035],
#  'integration': [196, 592, 988],
#  'intelligence': [226, 622, 1018],
#  'intelligent': [257, 329, 653, 725, 1049, 1121],
#  'intensity': [133, 529, 925],
#  'intent': [227, 623, 1019],
#  'interaction': [61, 237, 318, 457, 633, 714, 853, 1029, 1110],
#  'interactive': [248, 644, 1040],
#  'interactivity': [216, 612, 1008],
#  'interface': [338, 734, 1130],
#  'international': [323, 371, 719, 767, 1115, 1163],
#  'internet': [301, 697, 1093],
#  'interoperability': [70, 466, 862],
#  'interpolation': [129, 525, 921],
#  'intervention': [189, 334, 585, 730, 981, 1126],
#  'introduction': [367, 763, 1159],
#  'intruder': [18, 414, 810],
#  'intuitive': [220, 616, 1012],
#  'intuitiveguided': [196, 592, 988],
#  'invariant': [230, 626, 1022],
#  'investigate': [116,
#   318,
#   360,
#   368,
#   512,
#   714,
#   756,
#   764,
#   908,
#   1110,
#   1152,
#   1160],
#  'investigation': [54, 111, 377, 450, 507, 773, 846, 903, 1169],
#  'ip': [213, 609, 1005],
#  'iranian': [140, 536, 932],
#  'irrigation': [159, 555, 951],
#  'isa': [151, 547, 943],
#  'issue': [193, 201, 203, 589, 597, 599, 985, 993, 995],
#  'iubicom': [371, 767, 1163],
#  'job': [65, 461, 857],
#  'joint': [254, 650, 1046],
#  'journey': [204, 600, 996],
#  'judgement': [152, 548, 944],
#  'karun': [167, 563, 959],
#  'keep': [113, 378, 509, 774, 905, 1170],
#  'kems': [107, 503, 899],
#  'kernelbased': [137, 533, 929],
#  'kinodynamic': [96, 100, 492, 496, 888, 892],
#  'kmeans': [281, 677, 1073],
#  'know': [372, 768, 1164],
#  'knowledge': [52,
#   55,
#   187,
#   328,
#   340,
#   448,
#   451,
#   583,
#   724,
#   736,
#   844,
#   847,
#   979,
#   1120,
#   1132],
#  'knowledgebased': [345, 346, 741, 742, 1137, 1138],
#  'knowledgeofexternalrepresentations': [344, 740, 1136],
#  'lan': [9, 405, 801],
#  'language': [174, 242, 570, 638, 966, 1034],
#  'large': [171, 567, 963],
#  'largescale': [251, 366, 647, 762, 1043, 1158],
#  'lash': [109, 505, 901],
#  'layer': [143,
#   348,
#   350,
#   355,
#   358,
#   539,
#   744,
#   746,
#   751,
#   754,
#   935,
#   1140,
#   1142,
#   1147,
#   1150],
#  'lbe': [191, 587, 983],
#  'ldpccoded': [14, 410, 806],
#  'lead': [119, 121, 257, 515, 517, 653, 911, 913, 1049],
#  'leakage': [114, 381, 510, 777, 906, 1173],
#  'learn': [52,
#   54,
#   55,
#   56,
#   57,
#   59,
#   60,
#   119,
#   120,
#   121,
#   128,
#   169,
#   172,
#   177,
#   184,
#   188,
#   194,
#   196,
#   197,
#   204,
#   205,
#   207,
#   209,
#   216,
#   217,
#   220,
#   222,
#   229,
#   230,
#   231,
#   233,
#   241,
#   242,
#   243,
#   247,
#   257,
#   313,
#   314,
#   315,
#   316,
#   317,
#   323,
#   327,
#   329,
#   334,
#   375,
#   383,
#   448,
#   450,
#   451,
#   452,
#   453,
#   455,
#   456,
#   515,
#   516,
#   517,
#   524,
#   565,
#   568,
#   573,
#   580,
#   584,
#   590,
#   592,
#   593,
#   600,
#   601,
#   603,
#   605,
#   612,
#   613,
#   616,
#   618,
#   625,
#   626,
#   627,
#   629,
#   637,
#   638,
#   639,
#   643,
#   653,
#   709,
#   710,
#   711,
#   712,
#   713,
#   719,
#   723,
#   725,
#   730,
#   771,
#   779,
#   844,
#   846,
#   847,
#   848,
#   849,
#   851,
#   852,
#   911,
#   912,
#   913,
#   920,
#   961,
#   964,
#   969,
#   976,
#   980,
#   986,
#   988,
#   989,
#   996,
#   997,
#   999,
#   1001,
#   1008,
#   1009,
#   1012,
#   1014,
#   1021,
#   1022,
#   1023,
#   1025,
#   1033,
#   1034,
#   1035,
#   1039,
#   1049,
#   1105,
#   1106,
#   1107,
#   1108,
#   1109,
#   1115,
#   1119,
#   1121,
#   1126,
#   1167,
#   1175],
#  'learner': [55, 321, 322, 451, 717, 718, 847, 1113, 1114],
#  'learningbased': [376, 772, 1168],
#  'leg': [139, 535, 931],
#  'legendre': [156, 552, 948],
#  'lesson': [202, 598, 994],
#  'level': [26, 52, 327, 422, 448, 723, 818, 844, 1119],
#  'leverage': [362, 758, 1154],
#  'lifelong': [113, 378, 509, 774, 905, 1170],
#  'lifestyle': [185, 187, 189, 369, 581, 583, 585, 765, 977, 979, 981, 1161],
#  'lifetime': [50, 51, 154, 446, 447, 550, 842, 843, 946],
#  'light': [13,
#   15,
#   16,
#   18,
#   20,
#   23,
#   24,
#   409,
#   411,
#   412,
#   414,
#   416,
#   419,
#   420,
#   805,
#   807,
#   808,
#   810,
#   812,
#   815,
#   816],
#  'lightbulb': [324, 720, 1116],
#  'limit': [136, 532, 928],
#  'link': [184, 224, 225, 262, 580, 620, 621, 658, 976, 1016, 1017, 1054],
#  'linkfailure': [2, 398, 794],
#  'literature': [180, 576, 972],
#  'living': [362, 758, 1154],
#  'load': [76, 472, 868],
#  'loadbearing': [122, 126, 518, 522, 914, 918],
#  'local': [213, 609, 1005],
#  'location': [88, 484, 880],
#  'locationbased': [191, 587, 983],
#  'log': [113, 378, 509, 774, 905, 1170],
#  'longitudinal': [149, 545, 941],
#  'lookup': [292, 688, 1084],
#  'low': [129, 525, 921],
#  'lowfrequency': [389, 785, 1181],
#  'mac': [0, 396, 792],
#  'machine': [85,
#   88,
#   89,
#   90,
#   128,
#   137,
#   172,
#   247,
#   258,
#   383,
#   481,
#   484,
#   485,
#   486,
#   524,
#   533,
#   568,
#   643,
#   654,
#   779,
#   877,
#   880,
#   881,
#   882,
#   920,
#   929,
#   964,
#   1039,
#   1050,
#   1175],
#  'machinelearning': [125, 521, 917],
#  'magnetohydrodynamic': [143, 539, 935],
#  'main': [163, 559, 955],
#  'maintenance': [153, 154, 165, 166, 549, 550, 561, 562, 945, 946, 957, 958],
#  'make': [181, 577, 973],
#  'malayer': [133, 529, 925],
#  'malware': [115, 382, 511, 778, 907, 1174],
#  'manage': [339, 735, 1131],
#  'management': [63,
#   68,
#   160,
#   196,
#   255,
#   257,
#   387,
#   459,
#   464,
#   556,
#   592,
#   651,
#   653,
#   783,
#   855,
#   860,
#   952,
#   988,
#   1047,
#   1049,
#   1179],
#  'manet': [0, 1, 3, 6, 396, 397, 399, 402, 792, 793, 795, 798],
#  'manufacturing': [61, 65, 388, 457, 461, 784, 853, 857, 1180],
#  'mapping': [92, 488, 884],
#  'mass': [143, 539, 935],
#  'math': [333, 729, 1125],
#  'mathematical': [151, 170, 320, 547, 566, 716, 943, 962, 1112],
#  'mathematics': [322, 718, 1114],
#  'matrix': [246, 249, 254, 642, 645, 650, 1038, 1041, 1046],
#  'matter': [320, 716, 1112],
#  'mean': [49, 130, 445, 526, 841, 922],
#  'measure': [37, 249, 433, 645, 829, 1041],
#  'mechanic': [184, 580, 976],
#  'mediation': [69, 465, 861],
#  'medical': [224, 225, 364, 620, 621, 760, 1016, 1017, 1156],
#  'medium': [143, 539, 935],
#  'meducator': [224, 225, 620, 621, 1016, 1017],
#  'membrane': [161, 557, 953],
#  'memory': [238, 242, 634, 638, 1030, 1034],
#  'message': [262, 658, 1054],
#  'metaaffect': [323, 719, 1115],
#  'metaanalysis': [123,
#   138,
#   140,
#   141,
#   180,
#   519,
#   534,
#   536,
#   537,
#   576,
#   915,
#   930,
#   932,
#   933,
#   972],
#  'metaapl': [174, 570, 966],
#  'metacognitive': [322, 718, 1114],
#  'metacyber': [117, 513, 909],
#  'metadata': [217, 613, 1009],
#  'metaheuristics': [284, 680, 1076],
#  'metaregression': [140, 142, 536, 538, 932, 934],
#  'method': [28,
#   162,
#   168,
#   198,
#   250,
#   251,
#   254,
#   268,
#   269,
#   271,
#   292,
#   296,
#   383,
#   393,
#   424,
#   558,
#   564,
#   594,
#   646,
#   647,
#   650,
#   664,
#   665,
#   667,
#   688,
#   692,
#   779,
#   789,
#   820,
#   954,
#   960,
#   990,
#   1042,
#   1043,
#   1046,
#   1060,
#   1061,
#   1063,
#   1084,
#   1088,
#   1175,
#   1185],
#  'metric': [281, 298, 677, 694, 1073, 1090],
#  'metycoon': [208, 604, 1000],
#  'microarray': [132, 274, 275, 528, 670, 671, 924, 1066, 1067],
#  'middleware': [259, 261, 655, 657, 1051, 1053],
#  'migration': [2, 398, 794],
#  'minigames': [186, 582, 978],
#  'minimum': [144,
#   146,
#   157,
#   162,
#   168,
#   280,
#   540,
#   542,
#   553,
#   558,
#   564,
#   676,
#   936,
#   938,
#   949,
#   954,
#   960,
#   1072],
#  'mining': [80,
#   147,
#   272,
#   301,
#   379,
#   476,
#   543,
#   668,
#   697,
#   775,
#   872,
#   939,
#   1064,
#   1093,
#   1171],
#  'mixed': [311, 707, 1103],
#  'mobile': [68,
#   91,
#   92,
#   93,
#   94,
#   102,
#   115,
#   187,
#   193,
#   204,
#   382,
#   464,
#   487,
#   488,
#   489,
#   490,
#   498,
#   511,
#   583,
#   589,
#   600,
#   778,
#   860,
#   883,
#   884,
#   885,
#   886,
#   894,
#   907,
#   979,
#   985,
#   996,
#   1174],
#  'mobilecommerce': [263, 659, 1055],
#  'mode': [69, 356, 465, 752, 861, 1148],
#  'model': [13,
#   20,
#   26,
#   65,
#   70,
#   95,
#   97,
#   98,
#   118,
#   121,
#   122,
#   146,
#   149,
#   150,
#   151,
#   155,
#   157,
#   162,
#   165,
#   166,
#   168,
#   170,
#   239,
#   240,
#   256,
#   266,
#   302,
#   316,
#   321,
#   332,
#   337,
#   342,
#   370,
#   380,
#   384,
#   409,
#   416,
#   422,
#   461,
#   466,
#   491,
#   493,
#   494,
#   514,
#   517,
#   518,
#   542,
#   545,
#   546,
#   547,
#   551,
#   553,
#   558,
#   561,
#   562,
#   564,
#   566,
#   635,
#   636,
#   652,
#   662,
#   698,
#   712,
#   717,
#   728,
#   733,
#   738,
#   766,
#   776,
#   780,
#   805,
#   812,
#   818,
#   857,
#   862,
#   887,
#   889,
#   890,
#   910,
#   913,
#   914,
#   938,
#   941,
#   942,
#   943,
#   947,
#   949,
#   954,
#   957,
#   958,
#   960,
#   962,
#   1031,
#   1032,
#   1048,
#   1058,
#   1094,
#   1108,
#   1113,
#   1124,
#   1129,
#   1134,
#   1162,
#   1172,
#   1176],
#  'modular': [46, 442, 838],
#  'modulation': [24, 420, 816],
#  'module': [244, 640, 1036],
#  'moment': [324, 720, 1116],
#  'monitor': [87, 483, 879],
#  'monitoring': [198,
#   262,
#   303,
#   305,
#   306,
#   307,
#   308,
#   309,
#   310,
#   322,
#   594,
#   658,
#   699,
#   701,
#   702,
#   703,
#   704,
#   705,
#   706,
#   718,
#   990,
#   1054,
#   1095,
#   1097,
#   1098,
#   1099,
#   1100,
#   1101,
#   1102,
#   1114],
#  'monte': [22, 418, 814],
#  'montgomery': [108, 504, 900],
#  'mortality': [125, 521, 917],
#  'motion': [96, 492, 888],
#  'motivation': [187, 583, 979],
#  'motor': [83, 86, 240, 479, 482, 636, 875, 878, 1032],
#  'movement': [101, 497, 893],
#  'mttf': [44, 440, 836],
#  'multi': [2, 398, 794],
#  'multiagent': [78, 173, 474, 569, 870, 965],
#  'multichannel': [0, 2, 396, 398, 792, 794],
#  'multidisciplinary': [185, 581, 977],
#  'multihop': [23, 419, 815],
#  'multilayer': [16, 412, 808],
#  'multimetric': [272, 668, 1064],
#  'multimodal': [241, 243, 334, 637, 639, 730, 1033, 1035, 1126],
#  'multiobjective': [272, 275, 668, 671, 1064, 1067],
#  'multiparametric': [99, 495, 891],
#  'multipath': [0, 2, 396, 398, 792, 794],
#  'multiple': [77, 138, 293, 339, 473, 534, 689, 735, 869, 930, 1085, 1131],
#  'multiprecision': [32, 428, 824],
#  'multiprocessing': [30, 31, 426, 427, 822, 823],
#  'multiresolution': [265,
#   271,
#   277,
#   293,
#   294,
#   661,
#   667,
#   673,
#   689,
#   690,
#   1057,
#   1063,
#   1069,
#   1085,
#   1086],
#  'multivariate': [156, 163, 552, 559, 948, 955],
#  'multiwavelets': [156, 552, 948],
#  'muscle': [95,
#   97,
#   98,
#   99,
#   101,
#   491,
#   493,
#   494,
#   495,
#   497,
#   887,
#   889,
#   890,
#   891,
#   893],
#  'museum': [212, 311, 608, 707, 1004, 1103],
#  'mutual': [386, 782, 1178],
#  'nanostructure': [106, 502, 898],
#  'nao': [375, 771, 1167],
#  'natureinspired': [264, 660, 1056],
#  'navigation': [91, 92, 93, 94, 487, 488, 489, 490, 883, 884, 885, 886],
#  'need': [328, 724, 1120],
#  'network': [2,
#   16,
#   32,
#   50,
#   51,
#   59,
#   120,
#   124,
#   131,
#   132,
#   135,
#   146,
#   169,
#   171,
#   235,
#   245,
#   246,
#   251,
#   254,
#   257,
#   260,
#   261,
#   304,
#   307,
#   308,
#   364,
#   366,
#   398,
#   412,
#   428,
#   446,
#   447,
#   455,
#   516,
#   520,
#   527,
#   528,
#   531,
#   542,
#   565,
#   567,
#   631,
#   641,
#   642,
#   647,
#   650,
#   653,
#   656,
#   657,
#   700,
#   703,
#   704,
#   760,
#   762,
#   794,
#   808,
#   824,
#   842,
#   843,
#   851,
#   912,
#   916,
#   923,
#   924,
#   927,
#   938,
#   961,
#   963,
#   1027,
#   1037,
#   1038,
#   1043,
#   1046,
#   1049,
#   1052,
#   1053,
#   1096,
#   1099,
#   1100,
#   1156,
#   1158],
#  'neural': [16,
#   32,
#   131,
#   229,
#   237,
#   241,
#   412,
#   428,
#   527,
#   625,
#   633,
#   637,
#   808,
#   824,
#   923,
#   1021,
#   1029,
#   1033],
#  'neuron': [239, 635, 1031],
#  'neurophysiological': [198, 594, 990],
#  'neutral': [359, 755, 1151],
#  'neutron': [36,
#   38,
#   39,
#   41,
#   48,
#   432,
#   434,
#   435,
#   437,
#   444,
#   828,
#   830,
#   831,
#   833,
#   840],
#  'neutrongammaray': [37, 433, 829],
#  'new': [11,
#   28,
#   65,
#   83,
#   86,
#   206,
#   286,
#   407,
#   424,
#   461,
#   479,
#   482,
#   602,
#   682,
#   803,
#   820,
#   857,
#   875,
#   878,
#   998,
#   1078],
#  'newtonian': [357, 753, 1149],
#  'nmfbased': [249, 645, 1041],
#  'nmr': [40, 44, 45, 436, 440, 441, 832, 836, 837],
#  'noise': [21, 417, 813],
#  'nonadjacent': [85, 89, 481, 485, 877, 881],
#  'nonconjugate': [169, 565, 961],
#  'nondestructive': [391,
#   392,
#   394,
#   395,
#   787,
#   788,
#   790,
#   791,
#   1183,
#   1184,
#   1186,
#   1187],
#  'nondominated': [272, 668, 1064],
#  'nonequilibrium': [266, 662, 1058],
#  'nonformal': [59, 455, 851],
#  'nongaussian': [132, 146, 528, 542, 924, 938],
#  'nonholonomic': [102, 498, 894],
#  'nonlinear': [136, 532, 928],
#  'nonnegative': [246, 249, 254, 642, 645, 650, 1038, 1041, 1046],
#  'nonnewtonian': [347,
#   349,
#   351,
#   355,
#   743,
#   745,
#   747,
#   751,
#   1139,
#   1141,
#   1143,
#   1147],
#  'nonnormalized': [287, 683, 1079],
#  'normalize': [290, 686, 1082],
#  'novel': [84, 480, 876],
#  'nurse': [141, 537, 933],
#  'nutritional': [187, 583, 979],
#  'obesity': [199, 595, 991],
#  'object': [60,
#   209,
#   217,
#   222,
#   375,
#   456,
#   605,
#   613,
#   618,
#   771,
#   852,
#   1001,
#   1009,
#   1014,
#   1167],
#  'obstacle': [100, 496, 892],
#  'occupant': [383, 779, 1175],
#  'offtask': [317, 713, 1109],
#  'old': [140, 536, 932],
#  'one': [87, 483, 879],
#  'onestep': [282, 678, 1074],
#  'ongoing': [159, 555, 951],
#  'online': [251, 254, 302, 647, 650, 698, 1043, 1046, 1094],
#  'on‐line': [160, 556, 952],
#  'open': [186, 213, 226, 321, 582, 609, 622, 717, 978, 1005, 1018, 1113],
#  'operating': [111, 377, 507, 773, 903, 1169],
#  'opinion': [379, 775, 1171],
#  'optical': [19, 22, 415, 418, 811, 814],
#  'optimal': [82, 95, 99, 144, 478, 491, 495, 540, 874, 887, 891, 936],
#  'optimisation': [127, 523, 919],
#  'optimise': [153, 191, 549, 587, 945, 983],
#  'optimization': [100,
#   264,
#   267,
#   272,
#   275,
#   276,
#   280,
#   282,
#   284,
#   285,
#   289,
#   496,
#   660,
#   663,
#   668,
#   671,
#   672,
#   676,
#   678,
#   680,
#   681,
#   685,
#   892,
#   1056,
#   1059,
#   1064,
#   1067,
#   1068,
#   1072,
#   1074,
#   1076,
#   1077,
#   1081],
#  'optimize': [66,
#   144,
#   269,
#   273,
#   277,
#   462,
#   540,
#   665,
#   669,
#   673,
#   858,
#   936,
#   1061,
#   1065,
#   1069],
#  'optimum': [38, 434, 830],
#  'organisational': [183, 579, 975],
#  'orient': [33, 78, 429, 474, 825, 870],
#  'orthonormal': [156, 552, 948],
#  'output': [43, 439, 835],
#  'outreach': [104, 105, 500, 501, 896, 897],
#  'overfitting': [282, 678, 1074],
#  'overlap': [245, 641, 1037],
#  'overpopulation': [201, 597, 993],
#  'p2p': [63, 68, 459, 464, 855, 860],
#  'pair': [156, 552, 948],
#  'paircopula': [132, 144, 157, 163, 528, 540, 553, 559, 924, 936, 949, 955],
#  'parallel': [45, 441, 837],
#  'parallelism': [34, 430, 826],
#  'parameter': [162, 279, 558, 675, 954, 1071],
#  'parameterfree': [283, 679, 1075],
#  'parametric': [157, 553, 949],
#  'participatory': [226, 336, 622, 732, 1018, 1128],
#  'particle': [280, 289, 676, 685, 1072, 1081],
#  'partition': [34, 430, 826],
#  'passage': [136, 532, 928],
#  'password': [337, 339, 733, 735, 1129, 1131],
#  'path': [179, 575, 971],
#  'patient': [138, 141, 142, 364, 534, 537, 538, 760, 930, 933, 934, 1156],
#  'pattern': [12, 149, 408, 545, 804, 941],
#  'pedagogical': [335, 731, 1127],
#  'pedagogicallydriven': [211, 607, 1003],
#  'pedcross': [124, 520, 916],
#  'pedestrian': [124,
#   131,
#   135,
#   227,
#   228,
#   520,
#   527,
#   531,
#   623,
#   624,
#   916,
#   923,
#   927,
#   1019,
#   1020],
#  'pegaso': [199, 595, 991],
#  'people': [321, 335, 717, 731, 1113, 1127],
#  'perceptron': [16, 412, 808],
#  'perform': [272, 668, 1064],
#  'performance': [1,
#   5,
#   6,
#   15,
#   102,
#   121,
#   145,
#   306,
#   344,
#   397,
#   401,
#   402,
#   411,
#   498,
#   517,
#   541,
#   702,
#   740,
#   793,
#   797,
#   798,
#   807,
#   894,
#   913,
#   937,
#   1098,
#   1136],
#  'personalise': [207, 603, 999],
#  'perspective': [177, 573, 969],
#  'phenomenographic': [177, 573, 969],
#  'phenomenon': [282, 678, 1074],
#  'photon': [48, 444, 840],
#  'physical': [138, 534, 930],
#  'physician': [141, 537, 933],
#  'piecewise': [95, 273, 291, 491, 669, 687, 887, 1065, 1083],
#  'plan': [202, 598, 994],
#  'planning': [96, 257, 492, 653, 888, 1049],
#  'plate': [350, 352, 746, 748, 1142, 1144],
#  'platform': [213, 226, 253, 299, 609, 622, 649, 695, 1005, 1018, 1045, 1091],
#  'play': [187, 360, 583, 756, 979, 1152],
#  'pneumatic': [95,
#   97,
#   98,
#   99,
#   101,
#   491,
#   493,
#   494,
#   495,
#   497,
#   887,
#   889,
#   890,
#   891,
#   893],
#  'police': [130, 526, 922],
#  'policy': [113, 378, 509, 774, 905, 1170],
#  'pollution': [21, 417, 813],
#  'polynomial': [156, 552, 948],
#  'population': [266, 662, 1058],
#  'populationbased': [284, 680, 1076],
#  'porous': [143, 539, 935],
#  'pose': [91, 93, 135, 487, 489, 531, 883, 885, 927],
#  'position': [16, 386, 412, 782, 808, 1178],
#  'positive': [183, 579, 975],
#  'postgraduate': [387, 783, 1179],
#  'postural': [235, 631, 1027],
#  'potential': [333, 729, 1125],
#  'power': [50, 446, 842],
#  'powerlaw': [353, 358, 359, 749, 754, 755, 1145, 1150, 1151],
#  'practical': [110, 506, 902],
#  'practice': [328, 724, 1120],
#  'precision': [16, 159, 412, 555, 808, 951],
#  'precursor': [161, 557, 953],
#  'predict': [125, 126, 521, 522, 917, 918],
#  'prediction': [147, 543, 939],
#  'predictive': [97, 122, 240, 493, 518, 636, 889, 914, 1032],
#  'preface': [325, 326, 721, 722, 1117, 1118],
#  'preference': [342, 738, 1134],
#  'pregnancy': [123, 139, 519, 535, 915, 931],
#  'preinitialization': [284, 680, 1076],
#  'prepare': [221, 617, 1013],
#  'presentation': [324, 720, 1116],
#  'preserve': [245, 641, 1037],
#  'prevalence': [123,
#   139,
#   140,
#   141,
#   142,
#   519,
#   535,
#   536,
#   537,
#   538,
#   915,
#   931,
#   932,
#   933,
#   934],
#  'prevent': [199, 595, 991],
#  'preventative': [130, 526, 922],
#  'preventive': [153, 549, 945],
#  'principle': [94, 490, 886],
#  'prior': [152, 548, 944],
#  'priority': [262, 658, 1054],
#  'privacy': [114, 381, 510, 777, 906, 1173],
#  'proactive': [76, 472, 868],
#  'probabilistic': [122,
#   126,
#   133,
#   150,
#   153,
#   157,
#   164,
#   518,
#   522,
#   529,
#   546,
#   549,
#   553,
#   560,
#   914,
#   918,
#   925,
#   942,
#   945,
#   949,
#   956],
#  'probe': [389, 785, 1181],
#  'problem': [284, 333, 680, 729, 1076, 1125],
#  'procedure': [328, 724, 1120],
#  'process': [69,
#   127,
#   136,
#   145,
#   164,
#   250,
#   465,
#   523,
#   532,
#   541,
#   560,
#   646,
#   861,
#   919,
#   928,
#   937,
#   956,
#   1042],
#  'processing': [29,
#   33,
#   35,
#   36,
#   42,
#   43,
#   312,
#   425,
#   429,
#   431,
#   432,
#   438,
#   439,
#   708,
#   821,
#   825,
#   827,
#   828,
#   834,
#   835,
#   1104],
#  'processor': [29, 35, 425, 431, 821, 827],
#  'professional': [104, 105, 500, 501, 896, 897],
#  'professionalise': [113, 378, 509, 774, 905, 1170],
#  'profile': [64, 460, 856],
#  'program': [173, 174, 260, 387, 569, 570, 656, 783, 965, 966, 1052, 1179],
#  'programmable': [33, 429, 825],
#  'progress': [204, 600, 996],
#  'project': [387, 783, 1179],
#  'promas': [176, 572, 968],
#  'promote': [185, 581, 977],
#  'property': [106, 148, 502, 544, 898, 940],
#  'protocol': [0,
#   1,
#   6,
#   9,
#   10,
#   11,
#   61,
#   396,
#   397,
#   402,
#   405,
#   406,
#   407,
#   457,
#   792,
#   793,
#   798,
#   801,
#   802,
#   803,
#   853],
#  'protocol—model': [304, 700, 1096],
#  'prototype': [306, 309, 702, 705, 1098, 1101],
#  'prototyping': [305, 701, 1097],
#  'provide': [192, 200, 588, 596, 984, 992],
#  'provision': [75, 471, 867],
#  'prune': [265, 661, 1057],
#  'public': [203, 599, 995],
#  'pulmonary': [125, 521, 917],
#  'purpose': [327, 723, 1119],
#  'qos': [25, 74, 421, 470, 817, 866],
#  'qosdriven': [26, 422, 818],
#  'quality': [25, 27, 421, 423, 817, 819],
#  'quantify': [351, 747, 1143],
#  'quantization': [265, 661, 1057],
#  'query': [81, 343, 344, 477, 739, 740, 873, 1135, 1136],
#  'quick': [39, 49, 435, 445, 831, 841],
#  'radial': [364, 760, 1156],
#  'radiation': [12, 43, 408, 439, 804, 835],
#  'raise': [193, 203, 589, 599, 985, 995],
#  'rating': [209, 605, 1001],
#  'rational': [181, 337, 577, 733, 973, 1129],
#  'ray': [36, 38, 39, 41, 432, 434, 435, 437, 828, 830, 831, 833],
#  'readiness': [112, 508, 904],
#  'real': [231, 627, 1023],
#  'reality': [308, 311, 704, 707, 1100, 1103],
#  'realtime': [39, 435, 831],
#  'reason': [181, 577, 973],
#  'receiver': [1, 16, 397, 412, 793, 808],
#  'recent': [159, 555, 951],
#  'recogniser': [237, 633, 1029],
#  'recognition': [229,
#   230,
#   231,
#   232,
#   233,
#   234,
#   236,
#   333,
#   375,
#   625,
#   626,
#   627,
#   628,
#   629,
#   630,
#   632,
#   729,
#   771,
#   1021,
#   1022,
#   1023,
#   1024,
#   1025,
#   1026,
#   1028,
#   1125,
#   1167],
#  'recommendation': [62, 251, 254, 458, 647, 650, 854, 1043, 1046],
#  'record': [113, 364, 378, 509, 760, 774, 905, 1156, 1170],
#  'recoverable': [111, 377, 507, 773, 903, 1169],
#  'recurrent': [238, 634, 1030],
#  'reduce': [21, 264, 267, 293, 417, 660, 663, 689, 813, 1056, 1059, 1085],
#  'reduction': [295, 304, 691, 700, 1087, 1096],
#  'redundancy': [46, 442, 838],
#  'reed': [260, 656, 1052],
#  'reengineering': [361, 757, 1153],
#  'reference': [158, 554, 950],
#  'reflection': [333, 729, 1125],
#  'regime': [22, 418, 814],
#  'region': [133, 529, 925],
#  'regularshaped': [20, 416, 812],
#  'regulatory': [132, 528, 924],
#  'reinforce': [181, 389, 577, 785, 973, 1181],
#  'reinforcement': [376,
#   391,
#   394,
#   395,
#   772,
#   787,
#   790,
#   791,
#   1168,
#   1183,
#   1186,
#   1187],
#  'rejection': [161, 557, 953],
#  'relationship': [211, 221, 607, 617, 1003, 1013],
#  'relevance': [368, 764, 1160],
#  'reliability': [40, 152, 170, 436, 548, 566, 832, 944, 962],
#  'reliable': [2, 46, 398, 442, 794, 838],
#  'representation': [87,
#   238,
#   265,
#   269,
#   271,
#   315,
#   318,
#   341,
#   483,
#   634,
#   661,
#   665,
#   667,
#   711,
#   714,
#   737,
#   879,
#   1030,
#   1057,
#   1061,
#   1063,
#   1107,
#   1110,
#   1133],
#  'representational': [344, 740, 1136],
#  'repurposing': [209, 605, 1001],
#  'require': [125, 521, 917],
#  'rescue': [84, 480, 876],
#  'residential': [178, 190, 574, 586, 970, 982],
#  'resist': [3, 7, 399, 403, 795, 799],
#  'resolution': [74, 470, 866],
#  'resource': [224, 225, 620, 621, 1016, 1017],
#  'resourcing': [373, 769, 1165],
#  'restless': [139, 535, 931],
#  'retention': [188, 368, 584, 764, 980, 1160],
#  'retrieval': [64,
#   69,
#   118,
#   265,
#   277,
#   293,
#   294,
#   361,
#   365,
#   460,
#   465,
#   514,
#   661,
#   673,
#   689,
#   690,
#   757,
#   761,
#   856,
#   861,
#   910,
#   1057,
#   1069,
#   1085,
#   1086,
#   1153,
#   1157],
#  'reusability': [122, 126, 518, 522, 914, 918],
#  'reuse': [222, 618, 1014],
#  'review': [123,
#   138,
#   139,
#   141,
#   142,
#   180,
#   198,
#   371,
#   519,
#   534,
#   535,
#   537,
#   538,
#   576,
#   594,
#   767,
#   915,
#   930,
#   931,
#   933,
#   934,
#   972,
#   990,
#   1163],
#  'revisit': [110, 506, 902],
#  'reward': [136, 532, 928],
#  'right': [343, 739, 1135],
#  'rightsizing': [256, 652, 1048],
#  'risk': [155, 181, 195, 551, 577, 591, 947, 973, 987],
#  'river': [167, 563, 959],
#  'rlswed': [139, 535, 931],
#  'road': [194, 590, 986],
#  'robot': [91,
#   92,
#   93,
#   94,
#   96,
#   100,
#   102,
#   229,
#   231,
#   241,
#   242,
#   375,
#   487,
#   488,
#   489,
#   490,
#   492,
#   496,
#   498,
#   625,
#   627,
#   637,
#   638,
#   771,
#   883,
#   884,
#   885,
#   886,
#   888,
#   892,
#   894,
#   1021,
#   1023,
#   1033,
#   1034,
#   1167],
#  'robotic': [84, 234, 480, 630, 876, 1026],
#  'robotics': [243, 639, 1035],
#  'robust': [67,
#   71,
#   246,
#   249,
#   328,
#   329,
#   463,
#   467,
#   642,
#   645,
#   724,
#   725,
#   859,
#   863,
#   1038,
#   1041,
#   1120,
#   1121],
#  'robustness': [165, 166, 169, 171, 561, 562, 565, 567, 957, 958, 961, 963],
#  'rotate': [349,
#   351,
#   353,
#   354,
#   356,
#   357,
#   358,
#   359,
#   745,
#   747,
#   749,
#   750,
#   752,
#   753,
#   754,
#   755,
#   1141,
#   1143,
#   1145,
#   1146,
#   1148,
#   1149,
#   1150,
#   1151],
#  'rotatingdisk': [348, 744, 1140],
#  'rotor': [83,
#   85,
#   86,
#   87,
#   88,
#   89,
#   90,
#   479,
#   481,
#   482,
#   483,
#   484,
#   485,
#   486,
#   875,
#   877,
#   878,
#   879,
#   880,
#   881,
#   882],
#  'rough': [349, 745, 1141],
#  'rout': [4, 6, 8, 400, 402, 404, 796, 798, 800],
#  'route': [2, 398, 794],
#  'rsa': [108, 504, 900],
#  'rse': [211, 607, 1003],
#  'rule': [260, 261, 656, 657, 1052, 1053],
#  'rulebased': [259, 655, 1051],
#  'runtime': [260, 656, 1052],
#  'rust': [392, 393, 788, 789, 1184, 1185],
#  'safe': [127, 523, 919],
#  'safety': [45, 194, 262, 441, 590, 658, 837, 986, 1054],
#  'sample': [169, 171, 268, 565, 567, 664, 961, 963, 1060],
#  'saodv': [5, 401, 797],
#  'satellite': [28, 424, 820],
#  'satisfaction': [56, 452, 848],
#  'satisfy': [96, 100, 492, 496, 888, 892],
#  'scale': [158, 554, 950],
#  'scatter': [22, 418, 814],
#  'scenario': [124, 127, 520, 523, 916, 919],
#  'schema': [217, 613, 1009],
#  'scheme': [76, 269, 277, 290, 472, 665, 673, 686, 868, 1061, 1069, 1082],
#  'school': [333, 729, 1125],
#  'science': [113,
#   177,
#   197,
#   202,
#   226,
#   378,
#   509,
#   573,
#   593,
#   598,
#   622,
#   774,
#   905,
#   969,
#   989,
#   994,
#   1018,
#   1170],
#  'scisite': [393, 789, 1185],
#  'sclerosis': [138, 534, 930],
#  'scottish': [161, 557, 953],
#  'sea': [24, 420, 816],
#  'search': [84, 295, 361, 480, 691, 757, 876, 1087, 1153],
#  ...}

# %% [markdown]
# ## 3.  Query Processor

# %%
def demonstrate_query_processing():
    sample = input('Enter Search Terms: ')
    processed_query = tp1(sample)
    #print(f'User Search Query: {sample}')
    print(f'Processed Search Query: {processed_query}')
    return processed_query
    
#demonstrate_query_processing()

# %% [markdown]
# ### 3.1.  Split Query into individual terms

# %%
def split_query(terms):
    each = tp1(terms)
    return each.split()

dqp = demonstrate_query_processing()
dqp
print(f'Split Query: {split_query(dqp)}')
# Out:
# Enter Search Terms:  machine learning
# Processed Search Query: machine learn
# Split Query: ['machine', 'learn']

# %% [markdown]
# ### 3.2.  Boolean Functionalities

# %%
def union(lists):
    union = list(set.union(*map(set, lists)))
    union.sort()
    return union

def intersection(lists):
    intersect = list(set.intersection(*map(set, lists)))
    intersect.sort()
    return intersect

# %% [markdown]
# ### 3.3. Search Engine Function

# %%
def vertical_search_engine(df, query, index=indexes):
    query_split = split_query(query)
    retrieved = []
    for word in query_split:
        if word in index.keys():
            retrieved.append(index[word])
            
            
    # Ranked Retrieval
    if len(retrieved)>0:
        high_rank_result = intersection(retrieved)
        low_rank_result = union(retrieved) 
        c = [x for x in low_rank_result if x not in high_rank_result]      
        high_rank_result.extend(c)
        result = high_rank_result
        
        final_output = df[df.SN.isin(result)].reset_index(drop=True)
    
        # Return result in order of Intersection ----> Union
        dummy = pd.Series(result, name = 'SN').to_frame()
        result = pd.merge(dummy, final_output, on='SN', how = 'left')
        
    else:
        result = 'No result found'
    
    return result

# %%
def test_search_engine():
    xtest = scraped_db.copy()
    query = input("Enter your search query: ")
    return vertical_search_engine(xtest, query, indexed)
    
test_search_engine()
# Out:
# Enter your search query:  machine learning
#        SN                                              Title          Author  \
# 0     128  use machine learn algorithm develop clinical d...  daneshkhah, a.
# 1     172  towards generation attack tree use machine learn     sowka, k. j.
# 2     247  cps data stream analytics base machine learn c...         fei, x.
# 3     383  study several machine learn method estimate ca...      hintea, d.
# 4     524  use machine learn algorithm develop clinical d...  daneshkhah, a.
# ..    ...                                                ...             ...
# 154  1115  international workshop affect metaaffect data ...  grawemeyer, b.
# 155  1119  purpose level feedback exploratory learn envir...  grawemeyer, b.
# 156  1121  talk tutor explore learn intelligent tutor exp...  grawemeyer, b.
# 157  1126    intervention student multimodal learn activity   grawemeyer, b.
# 158  1167  object recognition algorithm implement nao rob...  karayaneva, y.
#
#        Published                                               Link
# 0     9 Jun 2021  https://pureportal.coventry.ac.uk/en/publicati...
# 1    24 Apr 2021  https://pureportal.coventry.ac.uk/en/publicati...
# 2       Jan 2019  https://pureportal.coventry.ac.uk/en/publicati...
# 3       Jul 2015  https://pureportal.coventry.ac.uk/en/publicati...
# 4     9 Jun 2021  https://pureportal.coventry.ac.uk/en/publicati...
# ..           ...                                                ...
# 154   1 Jan 2015  https://pureportal.coventry.ac.uk/en/publicati...
# 155   1 Jan 2015  https://pureportal.coventry.ac.uk/en/publicati...
# 156   1 Jan 2015  https://pureportal.coventry.ac.uk/en/publicati...
# 157   1 Jan 2014  https://pureportal.coventry.ac.uk/en/publicati...
# 158     Feb 2018  https://pureportal.coventry.ac.uk/en/publicati...
#
# [159 rows x 5 columns]

# %%
def final_engine(results):
    if type(results) != 'list':
        return results
        #print(results)
    else:
        for i in range(len(results)):
            printout = results.loc[i, :]
            #print(printout['Title'])
            #print(printout['Author'])
            #print(printout['Published'])
            #print(printout['Link'])
            #print('')

# %%
scraped_db['Author'].iloc[24]
# Out:
# 'ahmad, z.'

# %%
final_engine(test_search_engine())
# Out:
# Enter your search query:  machine learning
#        SN                                              Title          Author  \
# 0     128  use machine learn algorithm develop clinical d...  daneshkhah, a.
# 1     172  towards generation attack tree use machine learn     sowka, k. j.
# 2     247  cps data stream analytics base machine learn c...         fei, x.
# 3     383  study several machine learn method estimate ca...      hintea, d.
# 4     524  use machine learn algorithm develop clinical d...  daneshkhah, a.
# ..    ...                                                ...             ...
# 154  1115  international workshop affect metaaffect data ...  grawemeyer, b.
# 155  1119  purpose level feedback exploratory learn envir...  grawemeyer, b.
# 156  1121  talk tutor explore learn intelligent tutor exp...  grawemeyer, b.
# 157  1126    intervention student multimodal learn activity   grawemeyer, b.
# 158  1167  object recognition algorithm implement nao rob...  karayaneva, y.
#
#        Published                                               Link
# 0     9 Jun 2021  https://pureportal.coventry.ac.uk/en/publicati...
# 1    24 Apr 2021  https://pureportal.coventry.ac.uk/en/publicati...
# 2       Jan 2019  https://pureportal.coventry.ac.uk/en/publicati...
# 3       Jul 2015  https://pureportal.coventry.ac.uk/en/publicati...
# 4     9 Jun 2021  https://pureportal.coventry.ac.uk/en/publicati...
# ..           ...                                                ...
# 154   1 Jan 2015  https://pureportal.coventry.ac.uk/en/publicati...
# 155   1 Jan 2015  https://pureportal.coventry.ac.uk/en/publicati...
# 156   1 Jan 2015  https://pureportal.coventry.ac.uk/en/publicati...
# 157   1 Jan 2014  https://pureportal.coventry.ac.uk/en/publicati...
# 158     Feb 2018  https://pureportal.coventry.ac.uk/en/publicati...
#
# [159 rows x 5 columns]

# %% [markdown]
# ## 4. Schedule Crawler for every week
#
# To demonstrate a weekly scheduled crawling, the following parameters are defined:
#
# * `interval` : Represents number of days in reality. In this code, it represents only seconds for demonstration

# %%
days = 0
interval = 7
while days <= 1:
    scrape(mx)
    print(f"Crawled at {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f'Next crawl scheduled after {interval} days')
    time.sleep(interval)
    days = days + 1

# %% [markdown]
# # 5. GUI

# %%
from tkinter import *
from tkinter import messagebox
from PIL import Image, ImageTk 
from tkinter import scrolledtext
from pandastable import Table, TableModel
from contextlib import suppress
import warnings
warnings.filterwarnings('ignore')



image1 = Image.open('logo.png')
resized_image1 = image1.resize((500,300), Image.LANCZOS)

def search_engine_gui(image1):
    window = Tk()
    background_color = "#f3f3f3"
    text_color = "#395f92"
    window.configure(bg=background_color)
    window.title("Coventry Search Engine")
    window.geometry('1100x600')
    
    lbl = Label(window, text="Search Engine",bg=background_color, font=("Arial Bold", 30), padx=5, pady=5)
    lbl.grid(column=1, row=0)
    
    lbl2 = Label(window, text="Enter Keyword", bg=background_color,font=("Arial", 15), padx=5, pady=5)
    lbl2.grid(column=0, row=1)
    
    
    img = ImageTk.PhotoImage(image1)
    
    lbl3 = Label(image=img)
    lbl3.image = img
    lbl3.grid(column=1, row=3, padx=5, pady=5)
    
    
    
    query = Entry(window,width=40)
    query.grid(column=1, row=1,  padx=5, pady=5)
    
    results = Canvas(window, height=30, width=250)
    results.grid(column=1, row=2, padx=5, pady=5)
    
    # Entry
    def getInputBoxValue():
        userInput = query.get()
        return userInput

    
    # Button
    def clicked():
        search()
        #pass
        
    def no_result():
        messagebox.showwarning("Warning", "No results found. Please try different search terms")
        
    
    def search():
        xtest = scraped_db.copy()
        q = query.get()
        f = Frame(window)
        df = vertical_search_engine(xtest, q, indexed)
        if type(df) == str:
            no_result()
        else:
            pt = Table(results)
            try:
                table = pt = Table(results, dataframe=df)
                pt.show()
            except AttributeError:
                pass
            
    def close_window():
        if messagebox.askokcancel("Quit", "Quit Programme?"):
            window.destroy()
        
    
    btn = Button(window, text="Search",fg=text_color, bg=background_color, command=clicked)
    btn.grid(column=2, row=1)
    
    

    window.protocol("WM_DELETE_WINDOW", close_window)       
    window.mainloop()

# %%
search_engine_gui(resized_image1)
